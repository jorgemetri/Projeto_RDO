# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
import requests

# %%
# URL da API que você deseja acessar
token='eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
url=f'https://apiexterna.diariodeobra.app/v1/empresa'

# Fazendo a requisição GET
headers = {
    "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
}
response = requests.get(url, headers=headers)

try:
    response = requests.get(url, headers=headers)

    print("Status code:", response.status_code)
    print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

    # Somente tente converter em JSON se o status for 200 (ou conforme a API)
    if response.status_code == 200:
        print(response.content)
    else:
        print("A requisição não retornou 200. Verifique a mensagem acima.")

except Exception as e:
    print("Ocorreu um erro ao fazer a requisição:", e)
# Out:
# Status code: 200
# Resposta bruta: {"_id":"6582ff6f0605c1f2110c1742","nome":"LOPES MANUTEN\u00c7\u00c3O INDUSTRIAL E SERVI\u00c7OS LTDA","razaoSocial":"LOPES MANUTENCAO INDUSTRIAL E SERVICOS LTDA","cpfCnpj":"12.537.972\/0001-07","logoUrl":"https:\/\/cdndiariodeobra.azureedge.net\/empresas-logo\/6582ff6f0605c1f2110c1742\/378efc9f.png","log":{"totalObras":63,"totalObrasEmAndamento":33,"totalObrasConcluida":12,"totalObrasNaoIniciada":0,"totalObrasParalizada":18,"totalUsuarios":108,"totalUsuariosAtivos":107,"totalUsuariosDesativados":1,"totalRelatorios":7819,"totalRelatoriosPreenchendo":58,"totalRelatoriosAguardandoAprovacao":68,"totalRelatoriosAprovado":7693,"totalFotos":28300,"totalAnexos":0,"totalAnexosObra":0,"totalVideos":17,"tamanhoFotos":5306971530,"tamanhoVideos":39812864,"tamanhoAnexos":0,"tamanhoAnexosObra":0,"armazenamentoTotal":5346784394,"ltv":425,"ultimoAcesso":"18\/03\/2025 22:09:00","ultimoRelatorio":"18\/03\/2025 16:56:16","t":true,"exibirMensagemCobrancasVencidas":false,"ultimasCobrancasVencidas":[]}}
# b'{"_id":"6582ff6f0605c1f2110c1742","nome":"LOPES MANUTEN\\u00c7\\u00c3O INDUSTRIAL E SERVI\\u00c7OS LTDA","razaoSocial":"LOPES MANUTENCAO INDUSTRIAL E SERVICOS LTDA","cpfCnpj":"12.537.972\\/0001-07","logoUrl":"https:\\/\\/cdndiariodeobra.azureedge.net\\/empresas-logo\\/6582ff6f0605c1f2110c1742\\/378efc9f.png","log":{"totalObras":63,"totalObrasEmAndamento":33,"totalObrasConcluida":12,"totalObrasNaoIniciada":0,"totalObrasParalizada":18,"totalUsuarios":108,"totalUsuariosAtivos":107,"totalUsuariosDesativados":1,"totalRelatorios":7819,"totalRelatoriosPreenchendo":58,"totalRelatoriosAguardandoAprovacao":68,"totalRelatoriosAprovado":7693,"totalFotos":28300,"totalAnexos":0,"totalAnexosObra":0,"totalVideos":17,"tamanhoFotos":5306971530,"tamanhoVideos":39812864,"tamanhoAnexos":0,"tamanhoAnexosObra":0,"armazenamentoTotal":5346784394,"ltv":425,"ultimoAcesso":"18\\/03\\/2025 22:09:00","ultimoRelatorio":"18\\/03\\/2025 16:56:16","t":true,"exibirMensagemCobrancasVencidas":false,"ultimasCobrancasVencidas":[]}}'

# %%
def RetornarRelatorio(id):
# URL da API que você deseja acessar
  token='eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  url=f'https://apiexterna.diariodeobra.app/v1/obras/{id}/relatorios?limite=50&ordem=desc'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      print("Status code:", response.status_code)
      print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          print(response.content)
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)

# %%
retorno=RetornarRelatorio('665dccc26ac7560dd7038f22')
# Out:
# Status code: 200
# Resposta bruta: [{"_id":"67daa8e3e98e2b200b0ac215","data":"18\/03\/2025","dataFim":null,"diaDaSemana":"Ter\u00e7a-Feira","numero":155,"status":{"id":1,"descricao":"Preenchendo"},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"modeloDeRelatorioGlobal":{"_id":"6582ff6f0605c1f2110c1745","descricao":"Relat\u00f3rio Di\u00e1rio de Obra (RDO)"},"criadoPor":{"appIss":"app-web","dataHora":"19\/03\/2025 08:22","usuario":{"_id":"676d32797e49246eac0af305","nome":"Leonardo Simoes dos Reis","cargo":null,"email":"adm_samarco@lmimanutencao.com.br"}}},{"_id":"67daa82e51e932ab020648f8","data":"17\/03\/2025","dataFim":null,"diaDaSemana":"Segunda-Feira","numero":154,"status":{"id":1,"descricao":"Preenchendo"},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"modeloDeRelatorioGlobal":{"_id":"6582ff6f0605c1f2110c1745","descricao":"Relat\u00f3rio Di\u00e1rio de Obra (RDO)"},"criadoPor":{"appIss":"app-web","dataHora":"19\/03\/2025 08:19","usuario":{"_id":"676d32797e49246eac0af305","nome":"Leonardo Simoes dos Reis","cargo":null,"email":"adm_samarco@lmimanutencao.com.br"}}},{"_id":"67d96c9a175f39dbfd0918a2","data":"15\/03\/2025","dataFim":null,"diaDaSemana":"S\u00e1bado","numero":150,"status":{"id":4,"descricao":"Aprovado"},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"modeloDeRelatorioGlobal":{"_id":"6582ff6f0605c1f2110c1745","descricao":"Relat\u00f3rio Di\u00e1rio de Obra (RDO)"},"criadoPor":{"appIss":"app-web","dataHora":"18\/03\/2025 09:52","usuario":{"_id":"676d32797e49246eac0af305","nome":"Leonardo Simoes dos Reis","cargo":null,"email":"adm_samarco@lmimanutencao.com.br"}}},{"_id":"67daa7256baa1377d50e86e4","data":"14\/03\/2025","dataFim":null,"diaDaSemana":"Sexta-Feira","numero":153,"status":{"id":4,"descricao":"Aprovado"},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"modeloDeRelatorioGlobal":{"_id":"6582ff6f0605c1f2110c1745","descricao":"Relat\u00f3rio Di\u00e1rio de Obra (RDO)"},"criadoPor":{"appIss":"app-web","dataHora":"19\/03\/2025 08:14","usuario":{"_id":"65830119a87457b6f4034e53","nome":"Jo\u00e3o Pedro Mariotti","cargo":"Encarregado de Manuten\u00e7\u00e3o","email":"joao.mariotti@lmimanutencao.com.br"}}},{"_id":"67daa7048abb2794080a2e72","data":"13\/03\/2025","dataFim":null,"diaDaSemana":"Quinta-Feira","numero":152,"status":{"id":4,"descricao":"Aprovado"},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"modeloDeRelatorioGlobal":{"_id":"6582ff6f0605c1f2110c1745","descricao":"Relat\u00f3rio Di\u00e1rio de Obra (RDO)"},"criadoPor":{"appIss":"app-web","dataHora":"19\/03\/2025 08:14","usuario":{"_id":"65830119a87457b6f4034e53","nome":"Jo\u00e3o Pedro Mariotti","cargo":"Encarregado de Manuten\u00e7\u00e3o","email":"joao.mariotti@lmimanutencao.com.br"}}},{"_id":"67d441e7bacc5d35640ed122","data":"13\/03\/2025","dataFim":null,"diaDaSemana":"Quinta-Feira","numero":149,"status":{"id":4,"descricao":"Aprovado"},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"modeloDeRelatorioGlobal":{"_id":"6582ff6f0605c1f2110c1745","descricao":"Relat\u00f3rio Di\u00e1rio de Obra (RDO)"},"criadoPor":{"appIss":"app-web","dataHora":"14\/03\/2025 11:49","usuario":{"_id":"676d32797e49246eac0af305","nome":"Leonardo Simoes dos Reis","cargo":null,"email":"adm_samarco@lmimanutencao.com.br"}}},{"_id":"67daa57851a38f51de07fff2","data":"12\/03\/2025","dataFim":null,"diaDaSemana":"Quarta-Feira","numero":151,"status":{"id":4,"descricao":"Aprovado"},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"modeloDeRelatorioGlobal":{"_id":"6582ff6f0605c1f2110c1745","descricao":"Relat\u00f3rio Di\u00e1rio de Obra (RDO)"},"criadoPor":{"appIss":"app-web","dataHora":
},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"modeloDeRelatorioGlobal":{"_id":"6582ff6f0605c1f2110c1745","descricao":"Relat\\u00f3rio Di\\u00e1rio de Obra (RDO)"},"criadoPor":{"appIss":"app-web","dataHora":"19\\/03\\/2025 08:07","usuario":{"_id":"65830119a87457b6f4034e53","nome":"Jo\\u00e3o Pedro Mariotti","cargo":"Encarregado de Manuten\\u00e7\\u00e3o","email":"joao.mariotti@lmimanutencao.com.br"}}},{"_id":"67d441132875074fc50305c2","data":"12\\/03\\/2025" ...

# %%
retorno.json()
# Out:
# [{'_id': '67daa8e3e98e2b200b0ac215',
#   'data': '18/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Terça-Feira',
#   'numero': 155,
#   'status': {'id': 1, 'descricao': 'Preenchendo'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '19/03/2025 08:22',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67daa82e51e932ab020648f8',
#   'data': '17/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Segunda-Feira',
#   'numero': 154,
#   'status': {'id': 1, 'descricao': 'Preenchendo'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '19/03/2025 08:19',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67d96c9a175f39dbfd0918a2',
#   'data': '15/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sábado',
#   'numero': 150,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '18/03/2025 09:52',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67daa7256baa1377d50e86e4',
#   'data': '14/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 153,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '19/03/2025 08:14',
#    'usuario': {'_id': '65830119a87457b6f4034e53',
#     'nome': 'João Pedro Mariotti',
#     'cargo': 'Encarregado de Manutenção',
#     'email': 'joao.mariotti@lmimanutencao.com.br'}}},
#  {'_id': '67daa7048abb2794080a2e72',
#   'data': '13/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 152,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '19/03/2025 08:14',
#    'usuario': {'_id': '65830119a87457b6f4034e53',
#     'nome': 'João Pedro Mariotti',
#     'cargo': 'Encarregado de Manutenção',
#     'email': 'joao.mariotti@lmimanutencao.com.br'}}},
#  {'_id': '67d441e7bacc5d35640ed122',
#   'data': '13/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 149,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '14/03/2025 11:49',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67daa57851a38f51de07fff2',
#   'data': '12/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quarta-Feira',
#   'numero': 151,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '19/03/2025 08:07',
#    'usuario': {'_id': '65830119a87457b6f4034e53',
#     'nome': 'João Pedro Mariotti',
#     'cargo': 'Encarregado de Manutenção',
#     'email': 'joao.mariotti@lmimanutencao.com.br'}}},
#  {'_id': '67d441132875074fc50305c2',
#   'data': '12/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quarta-Feira',
#   'numero': 148,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '14/03/2025 11:45',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67d183955b4aeb3f3a037024',
#   'data': '11/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Terça-Feira',
#   'numero': 147,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '12/03/2025 09:52',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67d031caa4220cae84013444',
#   'data': '10/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Segunda-Feira',
#   'numero': 146,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '11/03/2025 09:51',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67ced539de348e645c081b74',
#   'data': '07/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 145,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '10/03/2025 09:04',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67ced4b2e979656c3d01e216',
#   'data': '06/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 144,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '10/03/2025 09:01',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67c9e4af715c2e8e7b0c4358',
#   'data': '28/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 143,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '06/03/2025 15:08',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67c1a84fa240fa94a90994c4',
#   'data': '27/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 142,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '28/02/2025 09:13',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67c078e4eb9a0bc76f0e60dc',
#   'data': '26/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quarta-Feira',
#   'numero': 141,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '27/02/2025 11:38',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67c07758ae20527b76096772',
#   'data': '25/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Terça-Feira',
#   'numero': 140,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '27/02/2025 11:31',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67c077156730c1cf560569f3',
#   'data': '24/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Segunda-Feira',
#   'numero': 139,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '27/02/2025 11:30',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67c076f595de15378e081f92',
#   'data': '22/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sábado',
#   'numero': 138,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '27/02/2025 11:30',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67bc67556ea999033e0cfcc5',
#   'data': '21/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 137,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '24/02/2025 09:34',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67bc67296a564441ae0f78a2',
#   'data': '20/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 136,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '24/02/2025 09:33',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67b71163e4b6c0e67c09dfc2',
#   'data': '19/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quarta-Feira',
#   'numero': 135,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '20/02/2025 08:26',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67b7112118666403dc054937',
#   'data': '18/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Terça-Feira',
#   'numero': 134,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '20/02/2025 08:25',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67b5c6adea58cfaf000fec82',
#   'data': '17/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Segunda-Feira',
#   'numero': 133,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '19/02/2025 08:55',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67b321d7430b2f02450fec72',
#   'data': '15/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sábado',
#   'numero': 132,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '17/02/2025 08:47',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67b321ae87921057780cda03',
#   'data': '14/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 131,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '17/02/2025 08:46',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67af2cfb9c2e39b18107e014',
#   'data': '13/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 130,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '14/02/2025 08:46',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67af2ca394bfebb22e064db3',
#   'data': '12/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quarta-Feira',
#   'numero': 129,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '14/02/2025 08:44',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67af2c89910b6b17180b5d02',
#   'data': '11/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Terça-Feira',
#   'numero': 128,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '14/02/2025 08:44',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67af2c52c437668b190aa193',
#   'data': '10/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Segunda-Feira',
#   'numero': 127,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '14/02/2025 08:43',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67aa070ee23a7c71bb03db52',
#   'data': '07/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 126,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '10/02/2025 11:02',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67aa06f1965df7183d0a95c2',
#   'data': '06/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 125,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '10/02/2025 11:02',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67aa06d10775c49f9f0a0205',
#   'data': '05/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quarta-Feira',
#   'numero': 124,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '10/02/2025 11:01',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67a393fbb62856186f007d73',
#   'data': '04/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Terça-Feira',
#   'numero': 123,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '05/02/2025 13:38',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67a1f0ca3b85850c5b064fe3',
#   'data': '03/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Segunda-Feira',
#   'numero': 122,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '04/02/2025 07:49',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '679e0daf7e1e4d7f8d0ed6c2',
#   'data': '31/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 121,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '01/02/2025 09:03',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '679bbbbf20ec5efa8507ab22',
#   'data': '30/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 120,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-android',
#    'dataHora': '30/01/2025 14:49',
#    'usuario': {'_id': '658305ba7b7a84621105f8e2',
#     'nome': 'Thadeu Alexander Quinteiro dos Santos',
#     'cargo': 'Supervisor de Manutenção',
#     'email': 'thadeu.santos@lmimanutencao.com.br'}}},
#  {'_id': '679bbb91fb241802f707a723',
#   'data': '29/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quarta-Feira',
#   'numero': 119,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-android',
#    'dataHora': '30/01/2025 14:49',
#    'usuario': {'_id': '658305ba7b7a84621105f8e2',
#     'nome': 'Thadeu Alexander Quinteiro dos Santos',
#     'cargo': 'Supervisor de Manutenção',
#     'email': 'thadeu.santos@lmimanutencao.com.br'}}},
#  {'_id': '679a3790db9c6e9491090863',
#   'data': '28/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Terça-Feira',
#   'numero': 118,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '29/01/2025 11:13',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67976f654717c8ba40016f03',
#   'data': '24/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 117,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '27/01/2025 08:35',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67937ba30adc86549e0afd46',
#   'data': '23/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 116,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '24/01/2025 08:38',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '679236e7898a1134e9048393',
#   'data': '22/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quarta-Feira',
#   'numero': 115,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '23/01/2025 09:32',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '6790ea2ac3c4ebb37f0c6312',
#   'data': '21/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Terça-Feira',
#   'numero': 114,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '22/01/2025 09:52',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '678fe9be06331c7ae301f12a',
#   'data': '20/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Segunda-Feira',
#   'numero': 113,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '21/01/2025 15:38',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '678e3fec9cac955fa804fae7',
#   'data': '17/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 112,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '20/01/2025 09:22',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '678a85cd33f4dbef100a5683',
#   'data': '16/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 111,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-android',
#    'dataHora': '17/01/2025 13:31',
#    'usuario': {'_id': '658305ba7b7a84621105f8e2',
#     'nome': 'Thadeu Alexander Quinteiro dos Santos',
#     'cargo': 'Supervisor de Manutenção',
#     'email': 'thadeu.santos@lmimanutencao.com.br'}}},
#  {'_id': '6787d947ab51b04c60022934',
#   'data': '15/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quarta-Feira',
#   'numero': 110,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-android',
#    'dataHora': '15/01/2025 12:50',
#    'usuario': {'_id': '658305ba7b7a84621105f8e2',
#     'nome': 'Thadeu Alexander Quinteiro dos Santos',
#     'cargo': 'Supervisor de Manutenção',
#     'email': 'thadeu.santos@lmimanutencao.com.br'}}},
#  {'_id': '6787985b982b83f72c0a6703',
#   'data': '14/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Terça-Feira',
#   'numero': 109,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '15/01/2025 08:13',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '6787984566eedc859b094d63',
#   'data': '13/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Segunda-Feira',
#   'numero': 108,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '15/01/2025 08:13',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '678518b575211a360208d972',
#   'data': '10/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 107,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '13/01/2025 10:44',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}},
#  {'_id': '67810f0d008417a1ca021bd3',
#   'data': '09/01/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 106,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '10/01/2025 09:14',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}}]

# %%
retorno.json()[0]
# Out:
# {'_id': '67daa8e3e98e2b200b0ac215',
#  'data': '18/03/2025',
#  'dataFim': None,
#  'diaDaSemana': 'Terça-Feira',
#  'numero': 155,
#  'status': {'id': 1, 'descricao': 'Preenchendo'},
#  'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#  'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#   'descricao': 'Relatório Diário de Obra (RDO)'},
#  'criadoPor': {'appIss': 'app-web',
#   'dataHora': '19/03/2025 08:22',
#   'usuario': {'_id': '676d32797e49246eac0af305',
#    'nome': 'Leonardo Simoes dos Reis',
#    'cargo': None,
#    'email': 'adm_samarco@lmimanutencao.com.br'}}}

# %%
retorno.json()[0]['_id']
# Out:
# '67daa8e3e98e2b200b0ac215'

# %%
# Out:
# list

# %%
relatorios  = []

# %%
for relatorio in retorno.json():
  relatorios.append(relatorio['_id'])

# %%
relatorios
# Out:
# ['67daa8e3e98e2b200b0ac215',
#  '67daa82e51e932ab020648f8',
#  '67d96c9a175f39dbfd0918a2',
#  '67daa7256baa1377d50e86e4',
#  '67daa7048abb2794080a2e72',
#  '67d441e7bacc5d35640ed122',
#  '67daa57851a38f51de07fff2',
#  '67d441132875074fc50305c2',
#  '67d183955b4aeb3f3a037024',
#  '67d031caa4220cae84013444',
#  '67ced539de348e645c081b74',
#  '67ced4b2e979656c3d01e216',
#  '67c9e4af715c2e8e7b0c4358',
#  '67c1a84fa240fa94a90994c4',
#  '67c078e4eb9a0bc76f0e60dc',
#  '67c07758ae20527b76096772',
#  '67c077156730c1cf560569f3',
#  '67c076f595de15378e081f92',
#  '67bc67556ea999033e0cfcc5',
#  '67bc67296a564441ae0f78a2',
#  '67b71163e4b6c0e67c09dfc2',
#  '67b7112118666403dc054937',
#  '67b5c6adea58cfaf000fec82',
#  '67b321d7430b2f02450fec72',
#  '67b321ae87921057780cda03',
#  '67af2cfb9c2e39b18107e014',
#  '67af2ca394bfebb22e064db3',
#  '67af2c89910b6b17180b5d02',
#  '67af2c52c437668b190aa193',
#  '67aa070ee23a7c71bb03db52',
#  '67aa06f1965df7183d0a95c2',
#  '67aa06d10775c49f9f0a0205',
#  '67a393fbb62856186f007d73',
#  '67a1f0ca3b85850c5b064fe3',
#  '679e0daf7e1e4d7f8d0ed6c2',
#  '679bbbbf20ec5efa8507ab22',
#  '679bbb91fb241802f707a723',
#  '679a3790db9c6e9491090863',
#  '67976f654717c8ba40016f03',
#  '67937ba30adc86549e0afd46',
#  '679236e7898a1134e9048393',
#  '6790ea2ac3c4ebb37f0c6312',
#  '678fe9be06331c7ae301f12a',
#  '678e3fec9cac955fa804fae7',
#  '678a85cd33f4dbef100a5683',
#  '6787d947ab51b04c60022934',
#  '6787985b982b83f72c0a6703',
#  '6787984566eedc859b094d63',
#  '678518b575211a360208d972',
#  '67810f0d008417a1ca021bd3']

# %%
def RetornaMaoObra(id_obra,id_relatorio):
  # URL da API que você deseja acessar
  token='eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  url=f'https://apiexterna.diariodeobra.app/v1/obras/{id}/relatorios?limite=50&ordem=desc'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      print("Status code:", response.status_code)
      print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          print(response.content)
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)

# %%
def VisualizarRelatorio(id_obra,id_relatorio):
  # URL da API que você deseja acessar
  token='eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  url=f'https://apiexterna.diariodeobra.app/v1/obras/{id_obra}/relatorios/{id_relatorio}'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      print("Status code:", response.status_code)
      print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          print(response.content)
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)

# %%
token='eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'

# %%
def RetornaObras():
  # URL da API que você deseja acessar

  url=f'https://apiexterna.diariodeobra.app/v1/obras'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      print("Status code:", response.status_code)
      print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          print(response.content)
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)

# %%
obras=RetornaObras()
# Out:
# Status code: 200
# Resposta bruta: [{"_id":"65859bfe2102858e56062f84","nome":"ALMOXARIFADO","totalRelatorios":254,"totalFotos":978,"status":{"id":3,"descricao":"Em Andamento"},"created":"22\/12\/2023 11:23:58","modified":"19\/03\/2025 07:56:46"},{"_id":"65fc3412adbaa9eff70fa3f2","nome":"CAMINHONETE 4X2 (GGA)","totalRelatorios":14,"totalFotos":31,"status":{"id":3,"descricao":"Em Andamento"},"created":"21\/03\/2024 10:20:18","modified":"17\/03\/2025 08:19:41"},{"_id":"65d4a2d0e071d51a750a5985","nome":"CAMINHONETE 4X2 (GMU)","totalRelatorios":15,"totalFotos":0,"status":{"id":3,"descricao":"Em Andamento"},"created":"20\/02\/2024 10:02:08","modified":"18\/02\/2025 11:38:16"},{"_id":"66cc55bca624ebcaa60b3012","nome":"CONDI\u00c7\u00c3O INSEGURA","totalRelatorios":151,"totalFotos":155,"status":{"id":3,"descricao":"Em Andamento"},"created":"26\/08\/2024 07:15:24","modified":"19\/03\/2025 08:10:23"},{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS","totalRelatorios":155,"totalFotos":7,"status":{"id":3,"descricao":"Em Andamento"},"created":"03\/06\/2024 11:01:38","modified":"19\/03\/2025 09:14:27"},{"_id":"658c457f5c026e631e011ac3","nome":"FERROPORT - REFOR\u00c7O ESTRUTURAL","totalRelatorios":427,"totalFotos":1127,"status":{"id":3,"descricao":"Em Andamento"},"created":"27
"status":{"id":3,"descricao":"Em Andamento"},"created":"22\\/01\\/2025 07:52:49","modified":"12\\/03\\/2025 11:23:38"},{"_id":"67d313ab4d3c97aabe028af2","nome":"GGA - MOMENTO III - Gilmar Galv\\u00e3o","totalRelatorios":40,"totalFotos":393,"status":{"id":3,"descricao":"Em Andamento"},"created":"13\\/03\\/2025 14:19:39","modified":"18\\/03\\/2025 17:21:10"},{"_id":"675993576728f2d1550bdbc4","nome":"GGA - MOMENTO III - Maur\\u00edcio Souza","totalRelatorios":245,"totalFotos":1816,"status":{"id":3,"descricao":"Em Andamento"},"created":"11\\/12\\/2024 10:27:51","modified":"17\\/03\\/2025 20:25:51"},{"_id":" ...

# %%
obra=obras.json()[0]['_id']
obra = '665dccc26ac7560dd7038f22'

# %% [markdown]
# # Relatórios da Obra

# %% [markdown]
# Essa função retorna todos os relatorios de uma determinada obra.

# %%
def RelatorioObras(id_obra,data_inicio,data_fim):
  # URL da API que você deseja acessar

  url=f'https://apiexterna.diariodeobra.app/v1/obras/{id_obra}/relatorios?dataInicio={data_inicio}&dataFim={data_fim}'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      print("Status code:", response.status_code)
      print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          print(response.content)
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)

# %%
relatorios = RelatorioObras('665dccc26ac7560dd7038f22','2025-03-13','2025-03-13')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d54eeebc1f74> in <cell line: 0>()
# ----> 1 relatorios = RelatorioObras('665dccc26ac7560dd7038f22','2025-03-13','2025-03-13')
#
# <ipython-input-19-068cd068d010> in RelatorioObras(id_obra, data_inicio, data_fim)
#       8       "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
#       9   }
# ---> 10   response = requests.get(url, headers=headers)
#      11
#      12   try:
#
# NameError: name 'requests' is not defined

# %%
relatorios.json()
# Out:
# [{'_id': '67daa7048abb2794080a2e72',
#   'data': '13/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 152,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '19/03/2025 08:14',
#    'usuario': {'_id': '65830119a87457b6f4034e53',
#     'nome': 'João Pedro Mariotti',
#     'cargo': 'Encarregado de Manutenção',
#     'email': 'joao.mariotti@lmimanutencao.com.br'}}},
#  {'_id': '67d441e7bacc5d35640ed122',
#   'data': '13/03/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Quinta-Feira',
#   'numero': 149,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '665dccc26ac7560dd7038f22', 'nome': 'DEIVISSON CAMPOS'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '14/03/2025 11:49',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}}]

# %%
relatorio1=relatorios.json()[0]['_id']

# %%
relatorio2=relatorios.json()[1]['_id']

# %%
vetor=VisualizarRelatorio(obra,'67d96c9a175f39dbfd0918a2')
# Out:
# Status code: 404
# Resposta bruta: {"mensagem":"Relat\u00f3rio n\u00e3o encontrado.","retorno":null}
# A requisição não retornou 200. Verifique a mensagem acima.

# %%
def VisualizarRelatorio(id_obra,id_relatorio):
  # URL da API que você deseja acessar

  url=f'https://apiexterna.diariodeobra.app/v1/obras/{id_obra}/relatorios/{id_relatorio}'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      print("Status code:", response.status_code)
      print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          print(response.content)
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)

# %%
visualizar=VisualizarRelatorio(obra,'67d183955b4aeb3f3a037024')
# Out:
# Status code: 200
# Resposta bruta: {"_id":"67d183955b4aeb3f3a037024","videos":[],"data":"11\/03\/2025","dataFim":null,"diaDaSemana":"Ter\u00e7a-Feira","numero":147,"prazo":{"contratual":315,"decorrido":295,"aVencer":20},"status":{"id":4,"descricao":"Aprovado"},"horarioDeTrabalho":{"expedienteInicio":null,"expedienteFim":null,"intervaloInicio":null,"intervaloFim":null,"horasTrabalhadas":null},"clima":{"manha":{"clima":"Claro","condicao":"Pratic\u00e1vel","ativo":true},"tarde":{"clima":"Claro","condicao":"Pratic\u00e1vel","ativo":true},"noite":{"clima":"Claro","condicao":"Pratic\u00e1vel","ativo":false},"indicePluviometrico":null},"maoDeObra":{"opcaoSelecionada":"personalizada","padrao":[],"personalizada":[{"_id":"66ba351f61cec501c30b2af3","registro":null,"nome":"DEMILSO VICOSI JUNIOR","funcao":"Mec\u00e2nico de Manuten\u00e7\u00e3o","presenca":true,"horaInicio":"06:50","horaFim":"17:02","horasIntervalo":"01:00","horasTrabalhadas":"09:12","ativo":null,"categoria":{"_id":"66cdc091641cae4e61099273","descricao":"DEIVISSON CAMPOS"}},{"_id":"65b101656ec12a201301c9b3","registro":null,"nome":"FILIPE ALMEIDA DA VITORIA","funcao":"T\u00e9cnico Mec Manuten\u00e7\u00e3o Polivalente","presenca":true,"horaInicio":"06:50","horaFim":"17:05","horasIntervalo":"01:00","horasTrabalhadas":"09:15","ativo":null,"categoria":{"_id":"66cdc091641cae4e61099273","descricao":"DEIVISSON CAMPOS"}}]},"equipamentos":[],"atividades":[{"maisOpcoes":false,"cronograma":false,"tarefaId":"643bbc65","item":null,"descricao":"* Apoio para equipe Samarco na desmobiliza\u00e7\u00e3o de materiais e ferramentas da P.U usina 03.\n\n* Apoio para equipe Samarco na U03-05TP021 sanar vazamento de pelotas.","observacao":"","porcentagem":null,"porcentagemAnterior":null,"controleDeProducao":{"ativo":false,"unidade":null,"quantidade":null,"realizado":null,"realizadoAnterior":null,"acumulado":null},"etapa":{"_id":null,"item":null,"descricao":null},"fotos":[],"ocorrencias":[],"videos":[],"horario":{"inicio":null,"fim":null,"total":null,"segundos":0,"descricao":null},"maoDeObra":[],"status":{"id":2,"descricao":"Em Andamento"}}],"ocorrencias":[],"comentarios":[],"galeriaDeFotos":[],"anexos":[],"controleDeMaterial":{"recebido":[],"utilizado":[]},"checklist":[],"vinculo":{"tipoDeVinculo":"obra","empresa":{"_id":"6582ff6f0605c1f2110c1742","nome":"LOPES MANUTEN\u00c7\u00c3O INDUSTRIAL E SERVI\u00c7OS LTDA"},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"cliente":{"_id":null,"nome":null},"ordemDeServico":{"_id":null,"nome":null,"numero":null,"responsavel":null}},"empresa":{"_id":"6582ff6f0605c1f2110c1742","nome":"LOPES MANUTEN\u00c7\u00c3O INDUSTRIAL E SERVI\u00c7OS LTDA","razaoSocial":"LOPES MANUTENCAO INDUSTRIAL E SERVICOS LTDA","cpfCnpj":"12.537.972\/0001-07","logo":"378efc9f.png","logoUrl":"https:\/\/cdndiariodeobra.azureedge.net\/empresas-logo\/6582ff6f0605c1f2110c1742\/378efc9f.png"},"obra":{"_id":"665dccc26ac7560dd7038f22","cadastroCompleto":true,"nome":"DEIVISSON CAMPOS","foto":"3a7fc4a5.jpg","fotoUrl":"https:\/\/cdndiariodeobra.azureedge.net\/obras-foto\/6582ff6f0605c1f2110c1742\/665dccc26ac7560dd7038f22\/3a7fc4a5.jpg","endereco":"SAMARCO - UBU","numeroContrato":"4600002789","dataInicio":"21\/05\/2024","dataFim":"31\/03\/2025","responsavel":"Deivisson Campos","tipoContratanteContratada":"Contratante","cliente":"Ana Clara Donna Volponi","clienteLogo":null,"clienteLogoUrl":null,"modulos":{"cronograma":false,"cronogramaEtapaRelatorio":false,"documentosDaObra":true}},"modeloDeRelatorio":{"descricao":"Relat\u00f3rio Di\u00e1rio de Obra (RDO)","itens":{"horarioDeTrabalho":false,"condicaoClimatica":false,"maoDeObra":true,"equipamento":true,"atividade":true,"ocorrencia":true,"controleDeMaterial":false,"comentario":false,"checklist":false,"galeriaDeFoto":true,"anexo":false,"assinatura":true,"video":true},"tipoDeData":"dia","tipoMaoDeObra":"personalizada","assinaturasTipo":"eletronica","assinaturasPaginas":"todas","assinaturasManual":[{"nome":"Assinatura"},{"nome":"Assinatura"}],"assinatur ...
# b'{"_id":"67d183955b4aeb3f3a037024","videos":[],"data":"11\\/03\\/2025","dataFim":null,"diaDaSemana":"Ter\\u00e7a-Feira","numero":147,"prazo":{"contratual":315,"decorrido":295,"aVencer":20},"status":{"id":4,"descricao":"Aprovado"},"horarioDeTrabalho":{"expedienteInicio":null,"expedienteFim":null,"intervaloInicio":null,"intervaloFim":null,"horasTrabalhadas":null},"clima":{"manha":{"clima":"Claro","condicao":"Pratic\\u00e1vel","ativo":true},"tarde":{"clima":"Claro","condicao":"Pratic\\u00e1vel","ativo":true},"noite":{"clima":"Claro","condicao":"Pratic\\u00e1vel","ativo":false},"indicePluviometrico":null},"maoDeObra":{"opcaoSelecionada":"personalizada","padrao":[],"personalizada":[{"_id":"66ba351f61cec501c30b2af3","registro":null,"nome":"DEMILSO VICOSI JUNIOR","funcao":"Mec\\u00e2nico de Manuten\\u00e7\\u00e3o","presenca":true,"horaInicio":"06:50","horaFim":"17:02","horasIntervalo":"01:00","horasTrabalhadas":"09:12","ativo":null,"categoria":{"_id":"66cdc091641cae4e61099273","descricao":"DEIVISSON CAMPOS"}},{"_id":"65b101656ec12a201301c9b3","registro":null,"nome":"FILIPE ALMEIDA DA VITORIA","funcao":"T\\u00e9cnico Mec Manuten\\u00e7\\u00e3o Polivalente","presenca":true,"horaInicio":"06:50","horaFim":"17:05","horasIntervalo":"01:00","horasTrabalhadas":"09:15","ativo":null,"categoria":{"_id":"66cdc091641cae4e61099273","descricao":"DEIVISSON CAMPOS"}}]},"equipamentos":[],"atividades":[{"maisOpcoes":false,"cronograma":false,"tarefaId":"643bbc65","item":null,"descricao":"* Apoio para equipe Samarco na desmobiliza\\u00e7\\u00e3o de materiais e ferramentas da P.U usina 03.\\n\\n* Apoio para equipe Samarco na U03-05TP021 sanar vazamento de pelotas.","observacao":"","porcentagem":null,"porcentagemAnterior":null,"controleDeProducao":{"ativo":false,"unidade":null,"quantidade":null,"realizado":null,"realizadoAnterior":null,"acumulado":null},"etapa":{"_id":null,"item":null,"descricao":null},"fotos":[],"ocorrencias":[],"videos":[],"horario":{"inicio":null,"fim":null,"total":null,"segundos":0,"descricao":null},"maoDeObra":[],"status":{"id":2,"descricao":"Em Andamento"}}],"ocorrencias":[],"comentarios":[],"galeriaDeFotos":[],"anexos":[],"controleDeMaterial":{"recebido":[],"utilizado":[]},"checklist":[],"vinculo":{"tipoDeVinculo":"obra","empresa":{"_id":"6582ff6f0605c1f2110c1742","nome":"LOPES MANUTEN\\u00c7\\u00c3O INDUSTRIAL E SERVI\\u00c7OS LTDA"},"obra":{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS"},"cliente":{"_id":null,"nome":null},"ordemDeServico":{"_id":null,"nome":null,"numero":null,"responsavel":null}},"empresa":{"_id":"6582ff6f0605c1f2110c1742","nome":"LOPES MANUTEN\\u00c7\\u00c3O INDUSTRIAL E SERVI\\u00c7OS LTDA","razaoSocial":"LOPES MANUTENCAO INDUSTRIAL E SERVICOS LTDA","cpfCnpj":"12.537.972\\/0001-07","logo":"378efc9f.png","logoUrl":"https:\\/\\/cdndiariodeobra.azureedge.net\\/empresas-logo\\/6582ff6f0605c1f2110c1742\\/378efc9f.png"},"obra":{"_id":"665dccc26ac7560dd7038f22","cadastroCompleto":true,"nome":"DEIVISSON CAMPOS","foto":"3a7fc4a5.jpg","fotoUrl":"https:\\/\\/cdndiariodeobra.azureedge.net\\/obras-foto\\/6582ff6f0605c1f2110c1742\\/665dccc26ac7560dd7038f22\\/3a7fc4a5.jpg","endereco":"SAMARCO - UBU","numeroContrato":"4600002789","dataInicio":"21\\/05\\/2024","dataFim":"31\\/03\\/2025","responsavel":"Deivisson Campos","tipoContratanteContratada":"Contratante","cliente":"Ana Clara Donna Volponi","clienteLogo":null,"clienteLogoUrl":null,"modulos":{"cronograma":false,"cronogramaEtapaRelatorio":false,"documentosDaObra":true}},"modeloDeRelatorio":{"descricao":"Relat\\u00f3rio Di\\u00e1rio de Obra (RDO)","itens":{"horarioDeTrabalho":false,"condicaoClimatica":false,"maoDeObra":true,"equipamento":true,"atividade":true,"ocorrencia":true,"controleDeMaterial":false,"comentario":false,"checklist":false,"galeriaDeFoto":true,"anexo":false,"assinatura":true,"video":true},"tipoDeData":"dia","tipoMaoDeObra":"personalizada","assinaturasTipo":"eletronica","assinaturasPaginas":"todas","assinaturasManual":[{"nome":"Assinatura"},{"nome" ...

# %%
visualizar.json()['maoDeObra']['personalizada']#Retorna pessoas de um relatorio dado um ID e um Relatorio
# Out:
# [{'_id': '66ba351f61cec501c30b2af3',
#   'registro': None,
#   'nome': 'DEMILSO VICOSI JUNIOR',
#   'funcao': 'Mecânico de Manutenção',
#   'presenca': True,
#   'horaInicio': '06:50',
#   'horaFim': '17:02',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:12',
#   'ativo': None,
#   'categoria': {'_id': '66cdc091641cae4e61099273',
#    'descricao': 'DEIVISSON CAMPOS'}},
#  {'_id': '65b101656ec12a201301c9b3',
#   'registro': None,
#   'nome': 'FILIPE ALMEIDA DA VITORIA',
#   'funcao': 'Técnico Mec Manutenção Polivalente',
#   'presenca': True,
#   'horaInicio': '06:50',
#   'horaFim': '17:05',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:15',
#   'ativo': None,
#   'categoria': {'_id': '66cdc091641cae4e61099273',
#    'descricao': 'DEIVISSON CAMPOS'}}]

# %%
import pandas as pd
excel = pd.DataFrame({'Num Relatorio','Nome Obra','Nome Empresa','Nome Func.','Nao Conforme?','Intervalo Hora','Horario SAM','Horario RDO','Incosisten. Acesso','Valor Horas Trabalhadas'})
excel
# Out:
#                          0
# 0           Intervalo Hora
# 1  Valor Horas Trabalhadas
# 2                Nome Obra
# 3            Num Relatorio
# 4            Nao Conforme?
# 5             Nome Empresa
# 6       Incosisten. Acesso
# 7               Nome Func.
# 8              Horario RDO
# 9              Horario SAM

# %% [markdown]
# # Acessando planilha

# %%
import requests

# %%
import pandas as pd

# Read Excel file
file_path = '/content/DETALHAMENTO DOS ACESSOS (17).xlsx'
df_acesso = pd.read_excel(file_path, engine='openpyxl')

# Display first 5 rows
print(df_acesso.head())
# Out:
#   Unidade  Classif.          ID                           Nome   Nº Contrato  \
# 0     UBU  TERCEIRO  96046002.0           ADAMO TEIXEIRA NOBRE  4.600003e+09
# 1     UBU  TERCEIRO  96058263.0             ADEMIR SANTOS ROSA  4.600003e+09
# 2     UBU  TERCEIRO  96009596.0         ADILSO DA SILVA RANGEL  4.600003e+09
# 3     UBU  TERCEIRO  96052255.0        ADONIAS DANTAS DE JESUS  4.600003e+09
# 4     UBU  TERCEIRO  96044201.0  ADVALDO RODRIGUES RAMOS FILHO  4.600003e+09
#
#                                Empresa           Gestor Contrato  \
# 0  LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 1  LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 2  LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 3  LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 4  LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
#
#                                      Área  DT Acesso 1ª Acesso
# 0  GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:30
# 1  GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:20
# 2  GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:34
# 3  GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:34
# 4  GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:25
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_acesso['Nome']
# Out:
# 0               ADAMO TEIXEIRA NOBRE
# 1                 ADEMIR SANTOS ROSA
# 2             ADILSO DA SILVA RANGEL
# 3            ADONIAS DANTAS DE JESUS
# 4      ADVALDO RODRIGUES RAMOS FILHO
#                    ...
# 192           WESLEY DA COSTA VIEIRA
# 193           WESLEY PEREIRA TAVARES
# 194                     WINDER PORTO
# 195                              NaN
# 196                              NaN
# Name: Nome, Length: 197, dtype: object

# %%
import pandas as pd
from io import StringIO

def create_dataframe_from_string(data_str: str) -> pd.DataFrame:
    """
    Given a multi-line string with tab-separated values,
    returns a pandas DataFrame.
    """
    # Use StringIO to simulate a file-like object from the string.
    data_io = StringIO(data_str)
    # Read the data into a DataFrame, assuming tab as the delimiter.
    df = pd.read_csv(data_io, delimiter="\t")
    return df

# Example data as provided:
data = """Nome Errado\tNome Correto
ALCILENE ALMEIDA DA VITORIA FRACALOSSI\tALCILENE ALMEIDA
ANDREA CRISTINA OLIVEIRA\tANDREA CRISTINA DE OLIVEIRA
CLEBERSON FRANCISCO FRANCA PEREIRA\tCLEBERSON FRANCISCO FRANCA
# 17           CLAUDENBERG SOUZA DE OLIVEIRA     CLAUDEMBERG SOUZA OLIVEIRA
# 18         JEFERSON BOMFIM REIS (96000534)           JEFERSON BOMFIM REIS

# %% [markdown]
# Codigo para alterar a planilha de acesso com os nomes corrigidos:

# %%
def CorrigirDados(df, df_referencia):
    for index, row in df.iterrows():
        if row['Nome'] in df_referencia['Nome Errado'].values:
            # Look up the correct name where 'Nome Errado' matches the current name
            correct_name = df_referencia.loc[
                df_referencia['Nome Errado'] == row['Nome'], 'Nome Correto'
            ].values[0]
            # Update the DataFrame using .at (iterrows() returns a copy, so direct assignment won't update the df)
            df.at[index, 'Nome'] = correct_name
    return df

# %%
df_acesso = CorrigirDados(df_acesso, df_referencia)

# %% [markdown]
# Confere se dados_corrigidos é igual ao que está na planilha de referencia:

# %%
for index,dados_corrigidos in dados_corrigidos.iterrows():#Itera por cada linha do dataframe
  if str(dados_corrigidos['Nome']).startswith('ALCILENE'):
    print(dados_corrigidos['Nome'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-dd977cef8c51> in <cell line: 0>()
# ----> 1 for index,dados_corrigidos in dados_corrigidos.iterrows():#Itera por cada linha do dataframe
#       2   if str(dados_corrigidos['Nome']).startswith('ALCILENE'):
#       3     print(dados_corrigidos['Nome'])
#
# NameError: name 'dados_corrigidos' is not defined

# %% [markdown]
# ## Acessar RDO

# %% [markdown]
# ## Pegar Obras

# %% [markdown]
# Essa função retorna um vetor de objetos  obras da LMI na samarco:

# %%
def PegarObras():
  # URL da API que você deseja acessar

  url=f'https://apiexterna.diariodeobra.app/v1/obras'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      print("Status code:", response.status_code)
      print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          print(response.content)
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)

# %% [markdown]
# Essa função irá entrar em todos os valores de obras e pegar o Id:

# %%
def RetornaVetorIdObras():
  obras = PegarObras()
  obras_id=[]
  for obra in obras.json():
    obras_id.append(obra['_id'])
  return obras_id

# %%
obras_id=RetornaVetorIdObras()
# Out:
# Status code: 200
# Resposta bruta: [{"_id":"65859bfe2102858e56062f84","nome":"ALMOXARIFADO","totalRelatorios":256,"totalFotos":978,"status":{"id":3,"descricao":"Em Andamento"},"created":"22\/12\/2023 11:23:58","modified":"21\/03\/2025 10:02:19"},{"_id":"65fc3412adbaa9eff70fa3f2","nome":"CAMINHONETE 4X2 (GGA)","totalRelatorios":14,"totalFotos":31,"status":{"id":3,"descricao":"Em Andamento"},"created":"21\/03\/2024 10:20:18","modified":"17\/03\/2025 08:19:41"},{"_id":"65d4a2d0e071d51a750a5985","nome":"CAMINHONETE 4X2 (GMU)","totalRelatorios":15,"totalFotos":0,"status":{"id":3,"descricao":"Em Andamento"},"created":"20\/02\/2024 10:02:08","modified":"18\/02\/2025 11:38:16"},{"_id":"66cc55bca624ebcaa60b3012","nome":"CONDI\u00c7\u00c3O INSEGURA","totalRelatorios":153,"totalFotos":155,"status":{"id":3,"descricao":"Em Andamento"},"created":"26\/08\/2024 07:15:24","modified":"21\/03\/2025 10:17:44"},{"_id":"665dccc26ac7560dd7038f22","nome":"DEIVISSON CAMPOS","totalRelatorios":157,"totalFotos":7,"status":{"id":3,"descricao":"Em Andamento"},"created":"03\/06\/2024 11:01:38","modified":"21\/03\/2025 10:03:50"},{"_id":"658c457f5c026e631e011ac3","nome":"FERROPORT - REFOR\u00c7O ESTRUTURAL","totalRelatorios":427,"totalFotos":1127,"status":{"id":3,"descricao":"Em Andamento"},"created":"27
#  '65859de59faa8ed8420b1694',
#  '65d49ef3b90b9c056508c713',
#  '664bd574cfc3848e3d0d9d42']

# %% [markdown]
# ## Pegar Relatórios de uma obra

# %% [markdown]
# Retorna todos os relatório de uma obra(id_obra).

# %%
def PegarRelatoriosObra(id_obra,data_inicio='2025-02-28',data_fim='2025-02-28'):
  url=f'https://apiexterna.diariodeobra.app/v1/obras/{id_obra}/relatorios?dataInicio={data_inicio}&dataFim={data_fim}'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)

# %%
relatorios = PegarRelatoriosObra(obras_id[0],'2025-02-28','2025-02-28')

# %%
relatorios.json()
# Out:
# [{'_id': '67c9dfd03da204978b0550b5',
#   'data': '28/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 252,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '65859bfe2102858e56062f84', 'nome': 'ALMOXARIFADO'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '06/03/2025 14:48',
#    'usuario': {'_id': '676d32797e49246eac0af305',
#     'nome': 'Leonardo Simoes dos Reis',
#     'cargo': None,
#     'email': 'adm_samarco@lmimanutencao.com.br'}}}]

# %% [markdown]
# ## Pega todos os relatorios das obras

# %% [markdown]
# Dado um vetor de id de obras essa função ira retornar um vetor no formato:
# [ {id_obra_1:[id_relatorio_1,id_relatorio_2,...]},{id_obra_2:[]},...,{id_obra_n:[id_relatorio_1,...]}]

# %%
def PegarTodosRelatoriosObras(obras_id, data_inicio, data_fim):
    ids_relatorios_obras = []
    for obra_id in obras_id:
        if obra_id:  # Check if obra_id is not empty or None
            relatorios = PegarRelatoriosObra(obra_id, data_inicio, data_fim)
            report_ids = []
            for relatorio in relatorios.json():
                report_ids.append(relatorio['_id'])
            # Only add the dictionary if there is at least one report
            if report_ids:
                ids_relatorios_obras.append({obra_id: report_ids})
    return ids_relatorios_obras

# %%
ids_relatorios = PegarTodosRelatoriosObras(obras_id,'2025-02-28','2025-02-28')

# %%
content = PegarRelatoriosObra(obras_id[15],'2025-02-28','2025-02-28')
content.json()
# Out:
# [{'_id': '67d3a112c892da6ad1035068',
#   'data': '28/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 18,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '67d313ab4d3c97aabe028af2',
#    'nome': 'GGA - MOMENTO III - Gilmar Galvão'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '14/03/2025 00:22',
#    'usuario': {'_id': '658aab444c8ae3f8330812f2',
#     'nome': 'Jordana de Souza Lima',
#     'cargo': 'Técnico de PPC',
#     'email': 'jordana@lmimanutencao.com.br'}}},
#  {'_id': '67d399907b030179cc089354',
#   'data': '28/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 16,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '67d313ab4d3c97aabe028af2',
#    'nome': 'GGA - MOMENTO III - Gilmar Galvão'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '13/03/2025 23:50',
#    'usuario': {'_id': '658aab444c8ae3f8330812f2',
#     'nome': 'Jordana de Souza Lima',
#     'cargo': 'Técnico de PPC',
#     'email': 'jordana@lmimanutencao.com.br'}}},
#  {'_id': '67d39813410d478c8e0bb57a',
#   'data': '28/02/2025',
#   'dataFim': None,
#   'diaDaSemana': 'Sexta-Feira',
#   'numero': 15,
#   'status': {'id': 4, 'descricao': 'Aprovado'},
#   'obra': {'_id': '67d313ab4d3c97aabe028af2',
#    'nome': 'GGA - MOMENTO III - Gilmar Galvão'},
#   'modeloDeRelatorioGlobal': {'_id': '6582ff6f0605c1f2110c1745',
#    'descricao': 'Relatório Diário de Obra (RDO)'},
#   'criadoPor': {'appIss': 'app-web',
#    'dataHora': '13/03/2025 23:44',
#    'usuario': {'_id': '658aab444c8ae3f8330812f2',
#     'nome': 'Jordana de Souza Lima',
#     'cargo': 'Técnico de PPC',
#     'email': 'jordana@lmimanutencao.com.br'}}}]

# %%
ids_relatorios
# Out:
# [{'65859bfe2102858e56062f84': ['67c9dfd03da204978b0550b5']},
#  {'66cc55bca624ebcaa60b3012': ['67c9dfea06198bd98f003682']},
#  {'665dccc26ac7560dd7038f22': ['67c9e4af715c2e8e7b0c4358']},
#  {'658c457f5c026e631e011ac3': ['67d1c4a2579c890fae015063']},
#  {'65859eca3d30cfd268041e99': ['67c1cac2dfc3c2658d0e1a50']},
#  {'67b86794697780816708c0d2': ['67d40948057d5d3ce40369b2']},
#  {'66045fa186b2a727640ba6e4': ['67c98e29e6ca1a11bc045bc6']},
#  {'66cc84b92253c1098301ef32': ['67cee02b6b8ba44aa10f02d6']},
#  {'6745d0a70e722ea8ab0f1474': ['67c99c2ae3d9f65962022e72']},
#  {'6792802a6374d523600b1733': ['67c99df846b38832b901a9c2']},
#  {'67d313ab4d3c97aabe028af2': ['67d3a112c892da6ad1035068',
#    '67d399907b030179cc089354',
#    '67d39813410d478c8e0bb57a']},
#  {'675993576728f2d1550bdbc4': ['67d3a4818c5fd68cd507a0fc',
#    '67d395fadd7aab06440d7d09']},
#  {'6745f3487741b65c6501a1e3': ['67c996b9a2537f3c6e004a43']},
#  {'66d706b97673fdaf8c072e04': ['67c9999bcbe1271ef003eac3']},
#  {'672902c003884527b3043696': ['67c997cbcf4c9da18007f752']},
#  {'6589fdceaf78e583cc020a2b': ['67c9ef93acbb6c1dbf02a2a2']},
#  {'658acc92df35c5b2d50804e3': ['67c9f1eea60588a1e806cf42']},
#  {'65b2ac170134203d220f8053': ['67c9f23b8783b2ca2702f963']},
#  {'674d94f4a28d766ea2048f68': ['67c6e369bacf80ded70909b2']},
#  {'658d97925d268ee5500041d4': ['67c9f5bba20ce13e32057653']},
#  {'6583047f50e3dc72f50bfe44': ['67bc7b6484cb688bb2034a52']},
#  {'65859e3201c81fbce706f404': ['67c9f60a54c2e6fc5700c652']},
#  {'65859cad679e0600ab0bcf52': ['67c9f7484e48b038e70098ed']},
#  {'67123a6a9c9ae4c9a0066fd6': ['67c24cbeb0d9705f2f005156']},
#  {'658427bed6894e5531039a75': ['67c2267973c9f6745001ff92']}]

# %%
primeiro_elemento = ids_relatorios[11]
lista_relatorios = list(primeiro_elemento.values())[0]

print(lista_relatorios)
# Out:
# ['67d3a4818c5fd68cd507a0fc', '67d395fadd7aab06440d7d09']

# %% [markdown]
# ## Visualizar Relatório

# %% [markdown]
# Essa função dado id obra e id relatorio retorna mao de obra:

# %%
mao_obras = []

# %%
def VisualizarRelatorio(id_obra,id_relatorio):
  url=f'https://apiexterna.diariodeobra.app/v1/obras/{id_obra}/relatorios/{id_relatorio}'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)


      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)

# %%
valor=VisualizarRelatorio('66cc55bca624ebcaa60b3012','67c9dfea06198bd98f003682')
valor.json()['maoDeObra']['personalizada']#Pessoa de um relatorio referente a uma obra
# Out:
# [{'_id': '658c03b71382102267091138',
#   'registro': None,
#   'nome': 'ADAMO TEIXEIRA NOBRE',
#   'funcao': 'Mecânico de Manutenção',
#   'presenca': True,
#   'horaInicio': '06:46',
#   'horaFim': '17:01',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:15',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '66015786c36a1aad1504ece8',
#   'registro': None,
#   'nome': 'ALEXANDRE DE LIMA COSTA',
#   'funcao': 'Mecânico de Manutenção',
#   'presenca': True,
#   'horaInicio': '06:50',
#   'horaFim': '17:00',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:10',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '658c047b4c15dcf6cc0dd54e',
#   'registro': None,
#   'nome': 'ALQUIMAR DA SILVA ALVES',
#   'funcao': 'Soldador Plasma/ER/Oxi-Corte',
#   'presenca': True,
#   'horaInicio': '06:47',
#   'horaFim': '17:02',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:15',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '658c013803d6927ed4035b24',
#   'registro': None,
#   'nome': 'CARLOS MAGNO DOS SANTOS CURITIBA',
#   'funcao': 'Mecânico de Manutenção',
#   'presenca': True,
#   'horaInicio': '06:56',
#   'horaFim': '17:02',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:06',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '658c056eb1d37df1340f0702',
#   'registro': None,
#   'nome': 'CLEBERSON FRANCISCO FRANCA',
#   'funcao': 'Técnico Mec Manutenção Polivalente',
#   'presenca': True,
#   'horaInicio': '06:52',
#   'horaFim': '17:00',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:08',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '658c03e75fbe509b7c0d4ec4',
#   'registro': None,
#   'nome': 'EDIMAR OLIVEIRA FERREIRA',
#   'funcao': 'Soldador Plasma/ER/Oxi-Corte',
#   'presenca': True,
#   'horaInicio': '06:50',
#   'horaFim': '17:03',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:13',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '658aa80025c7f0cb07087705',
#   'registro': None,
#   'nome': 'ELI BARRETO MOREIRA',
#   'funcao': 'Soldador Plasma/ER/Oxi-Corte',
#   'presenca': True,
#   'horaInicio': '08:47',
#   'horaFim': '16:56',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '07:09',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '676458480384b84a6102f1b9',
#   'registro': None,
#   'nome': 'EMERSON FERREIRA MEDEIROS',
#   'funcao': 'Soldador Plasma/ER/Oxi-Corte',
#   'presenca': True,
#   'horaInicio': '06:44',
#   'horaFim': '17:01',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:17',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '67645a052421371315028372',
#   'registro': None,
#   'nome': 'FRANK VIEIRA DOS SANTOS',
#   'funcao': 'Caldeireiro',
#   'presenca': True,
#   'horaInicio': '06:47',
#   'horaFim': '17:01',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:14',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '65842c48b13c588dbf0d99d2',
#   'registro': None,
#   'nome': 'JACKSON CARNEIRO CORREA',
#   'funcao': 'Mecânico de Manutenção',
#   'presenca': True,
#   'horaInicio': '06:45',
#   'horaFim': '16:55',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:10',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '658aa99dabc9af59af0f810c',
#   'registro': None,
#   'nome': 'JERRI ADRIANO SANTOS',
#   'funcao': 'Técnico Mec Manutenção Polivalente',
#   'presenca': True,
#   'horaInicio': '06:44',
#   'horaFim': '17:01',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:17',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '676561c8a7b73e050c008015',
#   'registro': None,
#   'nome': 'LEONARDO LIMA SILVA DA MATTA',
#   'funcao': 'Soldador Plasma/ER/Oxi-Corte',
#   'presenca': True,
#   'horaInicio': '06:50',
#   'horaFim': '17:01',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:11',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '6596895fe449ee3ca70e9969',
#   'registro': None,
#   'nome': 'NATHAN VIANA DE SOUZA',
#   'funcao': 'Mecânico de Manutenção Polivalente',
#   'presenca': True,
#   'horaInicio': '06:51',
#   'horaFim': '17:02',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:11',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '667c2ba759c2a73d92004e82',
#   'registro': None,
#   'nome': 'RODRIGO DA CRUZ MATTOS',
#   'funcao': 'Mecânico de Manutenção',
#   'presenca': True,
#   'horaInicio': '06:43',
#   'horaFim': '17:04',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:21',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '658c04be40a19dd88e09e525',
#   'registro': None,
#   'nome': 'VILMAR BORGAHRDT',
#   'funcao': 'Supervisor Máquinas Pátio e Porto',
#   'presenca': True,
#   'horaInicio': '06:48',
#   'horaFim': '17:02',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:14',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '658c04ffcb3d635ba80f4464',
#   'registro': None,
#   'nome': 'WALACE ROSA SIMOES',
#   'funcao': 'Técnico Mec Manutenção Polivalente',
#   'presenca': True,
#   'horaInicio': '06:57',
#   'horaFim': '17:01',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:04',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}},
#  {'_id': '658c049cc44c72b9d60344f4',
#   'registro': None,
#   'nome': 'WALLACE GUIMARAES PATUSSI',
#   'funcao': 'Soldador Plasma/ER/Oxi-Corte',
#   'presenca': True,
#   'horaInicio': '06:51',
#   'horaFim': '17:03',
#   'horasIntervalo': '01:00',
#   'horasTrabalhadas': '09:12',
#   'ativo': None,
#   'categoria': {'_id': '66c88014bd4296ae1705f579',
#    'descricao': 'CONDIÇÃO INSEGURA'}}]

# %% [markdown]
# ## Criando Tabela Mão de Obras

# %% [markdown]
# Essa função irá receber uma array mão de obras da forma:
#
# [{'id_mao_obra_1':['id_relatorio_1',...]}...]
#
# Essa função irá criar um dataframe com cada pessoa dos relatórios e assim retornar esse dataframe com as seguintes informações:
# - numero relatorio.
# - data RDO.
# - nome obra.
# - nome pessoa.
# - nome empresa.
# - nome pessoa.
# - não conforme?.
# - delta T.
# - horario SAM.
# - horario RDO.
# - incosistencia Acesso.
# - valor total horas trabalhadas.

# %%
primeiro_elemento = ids_relatorios[11]
lista_relatorios = list(primeiro_elemento.values())[0]

print(lista_relatorios)
# Out:
# ['67d3a4818c5fd68cd507a0fc', '67d395fadd7aab06440d7d09']

# %%
primeiro_elemento = ids_relatorios[11]
lista_relatorios = list(primeiro_elemento.values())[0]

# %%
def RetornaDataNumeroNomeObra(id_obra, id_relatorio, data_inicio='2025-02-28', data_fim='2025-02-28'):
    """
    Essa função irá, dado um id_obra e um id_relatorio, iterar por todos os relatórios de uma obra
    e pegar apenas o referente ao id, retornando um array com as seguintes informações:
      - numero do relatório
      - data RDO
      - nome da obra

    Args:
        id_obra (str): Id referente à obra.
        id_relatorio (str): Id referente ao relatório.
        data_inicio (str, opcional): Data inicial do filtro. Padrão '2025-02-28'.
        data_fim (str, opcional): Data final do filtro. Padrão '2025-02-28'.

    Returns:
        list: [numero_relatorio, data_RDO, nome_obra] ou None se não encontrar.
    """
    # PegarRelatoriosObra deve retornar algo que, ao chamar .json(), vire uma lista de dicionários
    relatorio = PegarRelatoriosObra(id_obra, data_inicio, data_fim)
    relatorio = relatorio.json()

    for r in relatorio:
        if r['_id'] == id_relatorio:
            # Ajuste aqui para retornar: número do relatório, data, nome da obra
            return [ r['data'],r['numero'], r['obra']['nome']]

    # Caso não encontre o relatório com o id especificado
    return None

# %%
RetornaDataNumeroNomeObra('66cc55bca624ebcaa60b3012','67c9dfea06198bd98f003682')
# Out:
# ['28/02/2025', 150, 'CONDIÇÃO INSEGURA']

# %%
import pandas as pd

def CriaRelatorioObra(vetorObraRelatorio):
    """
    Cria um DataFrame de relatórios de obras.

    Args:
        vetorObraRelatorio (list): lista de dicionários no formato:
            [
              {id_obra_1: [id_relatorio_1, id_relatorio_2, ...]},
              {id_obra_2: [id_relatorio_1, ...]},
              ...
              {id_obra_n: [id_relatorio_1, ...]}
            ]

    Returns:
        pd.DataFrame: com as colunas:
            - Numero Relatorio
            - Data RDO
            - Nome Obra
            - Nome Pessoa
            - Nome Empresa
            - Nome Func.
            - Nao Conforme?
            - Intervalo Hora
            - Horario SAM
            - Horario RDO
            - Incosisten. Acesso
            - Valor Horas Trabalhadas
    """
    columns = [
        'Numero Relatorio',
        'Data RDO',
        'Nome Obra',
        'Nome',
        'Nome Empresa',
        'Nao Conforme?',
        'Intervalo Hora',
        'Horario SAM',
        'Horario RDO',
        'Incosisten. Acesso',
        'Valor Horas Trabalhadas'
    ]
    df = pd.DataFrame(columns=columns)

    # vetorObraRelatorio é algo como [{id_obra1: [rel1, rel2]}, {id_obra2: [...]}]
    for elemento in vetorObraRelatorio:
        # elemento é um dicionário, pegamos a chave e o valor (lista de relatórios)
        id_obra = list(elemento.keys())[0]
        lista_relatorios = elemento[id_obra]

        for relatorio in lista_relatorios:
            # A função VisualizarRelatorio deve retornar o JSON com as pessoas:
            pessoas = VisualizarRelatorio(id_obra, relatorio).json()['maoDeObra']['personalizada']

            # Supondo que RetornaDataNumeroNomeObra retorne [data_RDO, numero, nome_obra]
            data_RDO, numero, nome_obra = RetornaDataNumeroNomeObra(id_obra, relatorio)

            # Montar uma linha do DataFrame para cada pessoa
            for pessoa in pessoas:
                row_data = [
                    numero,                          # Numero Relatorio
                    data_RDO,                        # Data RDO
                    nome_obra,                       # Nome Obra
                    pessoa.get('nome', ''),          # Nome Pessoa
                    'LMI',                           # Nome Empresa (ajuste se necessário)
                    0,                               # Nao Conforme? (ou False, se quiser boolean)
                    '',                              # Intervalo Hora (ex.: diferença de horas, se houver)
                    '',                              # Horario SAM (preencha se tiver a info)
                    pessoa.get('horaInicio', ''),    # Horario RDO (ou horaFim, conforme sua lógica)
                    '',                              # Incosisten. Acesso (preencha se necessário)
                    pessoa.get('horasTrabalhadas', 0)# Valor Horas Trabalhadas
                ]

                # Inserir a nova linha no DataFrame
                df.loc[len(df)] = row_data

    return df

# %%
df=CriaRelatorioObra(ids_relatorios)
df
# Out:
#      Numero Relatorio    Data RDO                     Nome Obra  \
# 0                 252  28/02/2025                  ALMOXARIFADO
# 1                 150  28/02/2025             CONDIÇÃO INSEGURA
# 2                 150  28/02/2025             CONDIÇÃO INSEGURA
# 3                 150  28/02/2025             CONDIÇÃO INSEGURA
# 4                 150  28/02/2025             CONDIÇÃO INSEGURA
# ..                ...         ...                           ...
# 130               309  28/02/2025  WIND FENCE - Douglas Batista
# 131               309  28/02/2025  WIND FENCE - Douglas Batista
# 132               309  28/02/2025  WIND FENCE - Douglas Batista
# 133               309  28/02/2025  WIND FENCE - Douglas Batista
# 134               309  28/02/2025  WIND FENCE - Douglas Batista
#
#                                  Nome Nome Empresa  Nao Conforme?  \
# 0     JEFERSON BOMFIM REIS (96000534)          LMI              0
# 1                ADAMO TEIXEIRA NOBRE          LMI              0
# 2             ALEXANDRE DE LIMA COSTA          LMI              0
# 3             ALQUIMAR DA SILVA ALVES          LMI              0
# 4    CARLOS MAGNO DOS SANTOS CURITIBA          LMI              0
# ..                                ...          ...            ...
# 130             ANTONIO SILVA RIBEIRO          LMI              0
# 131     ELIVELTRO OLIVEIRA DOS SANTOS          LMI              0
# 132       GUILHERME MARCHEZI NOGUEIRA          LMI              0
# 133                     JOEL FERREIRA          LMI              0
# 134          VINICIUS PIMENTEL SCHUTZ          LMI              0
#
#     Intervalo Hora Horario SAM Horario RDO Incosisten. Acesso  \
# 0                                    06:44
# 1                                    06:46
# 2                                    06:50
# 3                                    06:47
# 4                                    06:56
# ..             ...         ...         ...                ...
# 130                                  06:45
# 131                                  06:35
# 132                                  06:45
# 133                                  06:45
# 134                                  07:09
#
#     Valor Horas Trabalhadas
# 0                     09:10
# 1                     09:15
# 2                     09:10
# 3                     09:15
# 4                     09:06
# ..                      ...
# 130                   09:12
# 131                   09:19
# 132                   09:12
# 133                   09:12
# 134                   08:55
#
# [135 rows x 11 columns]

# %% [markdown]
# ## Comparando com a planilha informada

# %% [markdown]
# Agora iremos comparar a tabela criada com a planilha informada:

# %%
df = CorrigirDados(df,df_referencia)
df
# Out:
#      Numero Relatorio    Data RDO                     Nome Obra  \
# 0                 252  28/02/2025                  ALMOXARIFADO
# 1                 150  28/02/2025             CONDIÇÃO INSEGURA
# 2                 150  28/02/2025             CONDIÇÃO INSEGURA
# 3                 150  28/02/2025             CONDIÇÃO INSEGURA
# 4                 150  28/02/2025             CONDIÇÃO INSEGURA
# ..                ...         ...                           ...
# 130               309  28/02/2025  WIND FENCE - Douglas Batista
# 131               309  28/02/2025  WIND FENCE - Douglas Batista
# 132               309  28/02/2025  WIND FENCE - Douglas Batista
# 133               309  28/02/2025  WIND FENCE - Douglas Batista
# 134               309  28/02/2025  WIND FENCE - Douglas Batista
#
#                                  Nome Nome Empresa  Nao Conforme?  \
# 0                JEFERSON BOMFIM REIS          LMI              0
# 1                ADAMO TEIXEIRA NOBRE          LMI              0
# 2             ALEXANDRE DE LIMA COSTA          LMI              0
# 3             ALQUIMAR DA SILVA ALVES          LMI              0
# 4    CARLOS MAGNO DOS SANTOS CURITIBA          LMI              0
# ..                                ...          ...            ...
# 130             ANTONIO SILVA RIBEIRO          LMI              0
# 131     ELIVELTRO OLIVEIRA DOS SANTOS          LMI              0
# 132       GUILHERME MARCHEZI NOGUEIRA          LMI              0
# 133                     JOEL FERREIRA          LMI              0
# 134          VINICIUS PIMENTEL SCHUTZ          LMI              0
#
#     Intervalo Hora Horario SAM Horario RDO Incosisten. Acesso  \
# 0                                    06:44
# 1                                    06:46
# 2                                    06:50
# 3                                    06:47
# 4                                    06:56
# ..             ...         ...         ...                ...
# 130                                  06:45
# 131                                  06:35
# 132                                  06:45
# 133                                  06:45
# 134                                  07:09
#
#     Valor Horas Trabalhadas
# 0                     09:10
# 1                     09:15
# 2                     09:10
# 3                     09:15
# 4                     09:06
# ..                      ...
# 130                   09:12
# 131                   09:19
# 132                   09:12
# 133                   09:12
# 134                   08:55
#
# [135 rows x 11 columns]

# %% [markdown]
# agora criaremos a lógica para comparar as duas tabelas e por fim preencher os campos faltantes:

# %%
df_acesso
# Out:
#                                                Unidade  Classif.          ID  \
# 0                                                  UBU  TERCEIRO  96046002.0
# 1                                                  UBU  TERCEIRO  96058263.0
# 2                                                  UBU  TERCEIRO  96009596.0
# 3                                                  UBU  TERCEIRO  96052255.0
# 4                                                  UBU  TERCEIRO  96044201.0
# ..                                                 ...       ...         ...
# 192                                                UBU  TERCEIRO  96036912.0
# 193                                                UBU  TERCEIRO  96037541.0
# 194                                                UBU  TERCEIRO  96014012.0
# 195                                                NaN       NaN         NaN
# 196  Filtros aplicados:\nDES_EMPRESA é LOPES MANUTE...       NaN         NaN
#
#                               Nome   Nº Contrato  \
# 0             ADAMO TEIXEIRA NOBRE  4.600003e+09
# 1               ADEMIR SANTOS ROSA  4.600003e+09
# 2           ADILSO DA SILVA RANGEL  4.600003e+09
# 3          ADONIAS DANTAS DE JESUS  4.600003e+09
# 4    ADVALDO RODRIGUES RAMOS FILHO  4.600003e+09
# ..                             ...           ...
# 192         WESLEY DA COSTA VIEIRA  4.600003e+09
# 193         WESLEY PEREIRA TAVARES  4.600003e+09
# 194                   WINDER PORTO  4.600003e+09
# 195                            NaN           NaN
# 196                            NaN           NaN
#
#                                  Empresa           Gestor Contrato  \
# 0    LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 1    LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 2    LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 3    LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 4    LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# ..                                   ...                       ...
# 192  LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 193  LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 194  LOPES MANUTENCAO INDUSTRIAL E SERVI  PEDRO PAULO MOURA VIEIRA
# 195                                  NaN                       NaN
# 196                                  NaN                       NaN
#
#                                        Área  DT Acesso 1ª Acesso
# 0    GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:30
# 1    GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:20
# 2    GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:34
# 3    GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:34
# 4    GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:25
# ..                                      ...        ...       ...
# 192  GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:45
# 193  GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:35
# 194  GMU-COORDENACAO INSP PLANEJ MANUTENCAO 2025-02-28     06:40
# 195                                     NaN        NaT       NaN
# 196                                     NaN        NaT       NaN
#
# [197 rows x 10 columns]

# %%
import pandas as pd

for index, row in df.iterrows():
    if row['Nome'] in df_acesso['Nome'].values:  # Não houve inconsistência de acesso
        acessos_filtrados = df_acesso[(df_acesso['Nome'] == row['Nome']) &
                                      (df_acesso['DT Acesso'] == row['Data RDO'])]

        if not acessos_filtrados.empty:
            row_acesso = acessos_filtrados.iloc[0]  # Pega o primeiro acesso encontrado

            # Converte os horários para datetime para possibilitar a subtração
            horario_rdo = pd.to_datetime(row['Horario RDO'], format='%H:%M:%S')
            horario_sam = pd.to_datetime(row_acesso['1ª Acesso'], format='%H:%M:%S')

            # Calcula a diferença em horas
            intervalo_hora = (horario_rdo - horario_sam).total_seconds() / 3600

            # Converte os horários para o formato HH:MM:SS
            df.at[index, 'Horario SAM'] = horario_sam.strftime('%H:%M:%S')
            df.at[index, 'Intervalo Hora'] = f"{int(intervalo_hora):02d}:{int((intervalo_hora % 1) * 60):02d}:00"
            df.at[index, 'Nao Conforme?'] = 'Sim' if intervalo_hora >= 1 else 'Não'

# %%
import pandas as pd

def ConferenciaBases(df: pd.DataFrame, df_acesso: pd.DataFrame) -> pd.DataFrame:
    """
    Função que realiza a conferência entre as bases `df` e `df_acesso`, verificando inconsistências de acesso,
    calculando diferenças de horário e classificando registros como "Não Conforme" quando necessário.

    Parâmetros:
    - df: DataFrame principal contendo os registros de entrada e saída.
    - df_acesso: DataFrame contendo os horários de acesso dos funcionários.

    Retorno:
    - DataFrame `df` atualizado com as colunas 'Horario SAM', 'Intervalo Hora' e 'Nao Conforme?' preenchidas corretamente.
    """

    # Formatação inicial das colunas de data e horário
    # Converter 'Horario RDO' para datetime64[ns]
    df['Horario RDO'] = pd.to_datetime(df['Horario RDO'], format='%H:%M')
    # Converter 'Data RDO' para datetime64[ns]
    df['Data RDO'] = pd.to_datetime(df['Data RDO'])
    # Converter 'Horario RDO' para datetime64[ns]
    df_acesso['1ª Acesso'] = pd.to_datetime(df_acesso['1ª Acesso'], format='%H:%M')
    df['Nao Conforme?'] = df['Nao Conforme?'].astype(str)

    # Formatação da coluna de acesso
    #df_acesso['1ª Acesso'] = pd.to_datetime(df_acesso['1ª Acesso'], format='%d/%m/%Y %H:%M', errors='coerce').dt.time

    # Marca inconsistências de acesso
    df['Incosisten. Acesso'] = df['Nome'].apply(lambda x: 'Não' if x in df_acesso['Nome'].values else 'Sim')

    # Iteração sobre o DataFrame para conferência dos horários
    for index, row in df.iterrows():
        if row['Nome'] in df_acesso['Nome'].values:  # Se o nome estiver na base de acesso
            acessos_filtrados = df_acesso[(df_acesso['Nome'] == row['Nome']) &
                                          (df_acesso['DT Acesso'] == row['Data RDO'])]

            if not acessos_filtrados.empty:
                row_acesso = acessos_filtrados.iloc[0]  # Pega o primeiro acesso encontrado

                # Converte os horários para datetime para possibilitar a subtração
                horario_rdo = pd.to_datetime(row['Horario RDO'], format='%H:%M:%S', errors='coerce')
                horario_sam = pd.to_datetime(row_acesso['1ª Acesso'], format='%H:%M:%S', errors='coerce')

                # Verifica se os horários são válidos
                if pd.isna(horario_rdo) or pd.isna(horario_sam):
                    continue  # Pula a iteração se houver valores inválidos

                # Calcula a diferença em horas
                intervalo_hora = ( horario_sam-horario_rdo ).total_seconds() / 3600

                # Converte os horários para o formato HH:MM:SS
                df.at[index, 'Horario SAM'] = horario_sam.strftime('%H:%M:%S')
                df.at[index,'Horario RDO'] = horario_rdo.strftime('%H:%M:%S')
                df.at[index, 'Intervalo Hora'] = f"{int(intervalo_hora):02d}:{int((intervalo_hora % 1) * 60):02d}:00"
                df.at[index, 'Nao Conforme?'] = 'Sim' if intervalo_hora >= 0.5 else 'Não'

    return df

# %%
import pandas as pd

def ConferenciaBases(df: pd.DataFrame, df_acesso: pd.DataFrame) -> pd.DataFrame:
    """
    Função que realiza a conferência entre as bases `df` e `df_acesso`, verificando inconsistências de acesso,
    calculando diferenças de horário e classificando registros como "Não Conforme" quando necessário.

    Parâmetros:
    - df: DataFrame principal contendo os registros de entrada e saída.
    - df_acesso: DataFrame contendo os horários de acesso dos funcionários.

    Retorno:
    - DataFrame `df` atualizado com as colunas 'Horario SAM', 'Intervalo Hora' e 'Nao Conforme?' preenchidas corretamente.
    """

    # Formatação inicial das colunas de data e horário
    # Converter 'Horario RDO' para datetime e depois para string HH:MM
    df['Horario RDO'] = pd.to_datetime(df['Horario RDO'], format='%H:%M', errors='coerce').dt.strftime('%H:%M')
    df['Data RDO'] = pd.to_datetime(df['Data RDO'], dayfirst=True, errors='coerce')
    df_acesso['1ª Acesso'] = pd.to_datetime(df_acesso['1ª Acesso'], format='%H:%M', errors='coerce')
    df_acesso['DT Acesso'] = pd.to_datetime(df_acesso['DT Acesso'], dayfirst=True, errors='coerce')

    # Inicializar colunas se não existirem
    df['Nao Conforme?'] = df.get('Nao Conforme?', 'Não').astype(str)
    df['Horario SAM'] = df.get('Horario SAM', pd.NaT)
    df['Intervalo Hora'] = df.get('Intervalo Hora', pd.NaT)

    # Marca inconsistências de acesso
    df['Incosisten. Acesso'] = df['Nome'].apply(lambda x: 'Não' if x in df_acesso['Nome'].values else 'Sim')

    # Iteração sobre o DataFrame para conferência dos horários
    for index, row in df.iterrows():
        if row['Nome'] in df_acesso['Nome'].values:  # Se o nome estiver na base de acesso
            acessos_filtrados = df_acesso[(df_acesso['Nome'] == row['Nome']) &
                                        (df_acesso['DT Acesso'] == row['Data RDO'])]

            if not acessos_filtrados.empty:
                row_acesso = acessos_filtrados.iloc[0]  # Pega o primeiro acesso encontrado

                # Converter 'Horario RDO' de volta para datetime para cálculos
                horario_rdo = pd.to_datetime(row['Horario RDO'], format='%H:%M', errors='coerce')
                horario_sam = row_acesso['1ª Acesso']

                # Verifica se os horários são válidos
                if pd.isna(horario_rdo) or pd.isna(horario_sam):
                    continue  # Pula a iteração se houver valores inválidos

                # Combinar data de 'Data RDO' com os horários para cálculo correto
                data_base = row['Data RDO']
                if pd.notna(data_base):
                    horario_rdo_completo = pd.Timestamp.combine(data_base.date(), horario_rdo.time())
                    horario_sam_completo = pd.Timestamp.combine(data_base.date(), horario_sam.time())

                    # Calcula a diferença em horas (decimal)
                    intervalo_hora = (horario_sam_completo - horario_rdo_completo).total_seconds() / 3600

                    # Converter para formato HH:MM
                    intervalo_abs = abs(intervalo_hora)  # Usa o valor absoluto
                    horas = int(intervalo_abs)
                    minutos = int((intervalo_abs - horas) * 60)
                    intervalo_formatado = f"{horas:02d}:{minutos:02d}"

                    # Atribuir valores às colunas
                    df.at[index, 'Horario SAM'] = horario_sam.strftime('%H:%M')
                    df.at[index, 'Horario RDO'] = horario_rdo.strftime('%H:%M')  # Garantir que seja apenas HH:MM
                    df.at[index, 'Intervalo Hora'] = intervalo_formatado  # Armazena como HH:MM
                    df.at[index, 'Nao Conforme?'] = 'Sim' if intervalo_abs >= 0.5 else 'Não'

    return df

# %%
df_corrigido = ConferenciaBases(df, df_acesso)

# %%
df_corrigido
# Out:
#      Numero Relatorio   Data RDO                     Nome Obra  \
# 0                 252 2025-02-28                  ALMOXARIFADO
# 1                 150 2025-02-28             CONDIÇÃO INSEGURA
# 2                 150 2025-02-28             CONDIÇÃO INSEGURA
# 3                 150 2025-02-28             CONDIÇÃO INSEGURA
# 4                 150 2025-02-28             CONDIÇÃO INSEGURA
# ..                ...        ...                           ...
# 130               309 2025-02-28  WIND FENCE - Douglas Batista
# 131               309 2025-02-28  WIND FENCE - Douglas Batista
# 132               309 2025-02-28  WIND FENCE - Douglas Batista
# 133               309 2025-02-28  WIND FENCE - Douglas Batista
# 134               309 2025-02-28  WIND FENCE - Douglas Batista
#
#                                  Nome Nome Empresa Nao Conforme?  \
# 0                JEFERSON BOMFIM REIS          LMI           Não
# 1                ADAMO TEIXEIRA NOBRE          LMI           Não
# 2             ALEXANDRE DE LIMA COSTA          LMI           Não
# 3             ALQUIMAR DA SILVA ALVES          LMI           Não
# 4    CARLOS MAGNO DOS SANTOS CURITIBA          LMI           Não
# ..                                ...          ...           ...
# 130             ANTONIO SILVA RIBEIRO          LMI           Não
# 131     ELIVELTRO OLIVEIRA DOS SANTOS          LMI           Não
# 132       GUILHERME MARCHEZI NOGUEIRA          LMI           Não
# 133                     JOEL FERREIRA          LMI           Não
# 134          VINICIUS PIMENTEL SCHUTZ          LMI           Não
#
#     Intervalo Hora Horario SAM Horario RDO Incosisten. Acesso  \
# 0            00:18       06:26       06:44                Não
# 1            00:16       06:30       06:46                Não
# 2            00:16       06:34       06:50                Não
# 3            00:17       06:30       06:47                Não
# 4            00:18       06:38       06:56                Não
# ..             ...         ...         ...                ...
# 130          00:07       06:38       06:45                Não
# 131          00:23       06:12       06:35                Não
# 132          00:07       06:38       06:45                Não
# 133          00:07       06:38       06:45                Não
# 134          00:21       06:48       07:09                Não
#
#     Valor Horas Trabalhadas
# 0                     09:10
# 1                     09:15
# 2                     09:10
# 3                     09:15
# 4                     09:06
# ..                      ...
# 130                   09:12
# 131                   09:19
# 132                   09:12
# 133                   09:12
# 134                   08:55
#
# [135 rows x 11 columns]

# %%
import pandas as pd

def salvar_dataframe_em_excel(df: pd.DataFrame, nome_arquivo: str):
    """
    Salva um DataFrame em um arquivo Excel (.xlsx).

    Parâmetros:
    - df: DataFrame a ser salvo.
    - nome_arquivo: Nome do arquivo de saída (incluindo .xlsx).
    """
    try:
        df.to_excel(nome_arquivo, index=False, engine='openpyxl')
        print(f"Arquivo salvo com sucesso: {nome_arquivo}")
    except Exception as e:
        print(f"Erro ao salvar o arquivo: {e}")

# %%
salvar_dataframe_em_excel(df_corrigido, 'base_final.xlsx')
# Out:
# Arquivo salvo com sucesso: base_final.xlsx

# %% [markdown]
# ###   Teste App

# %%
def PegarRelatoriosObra(id_obra, data_inicio='2025-02-28', data_fim='2025-02-28'):
    url = f'https://apiexterna.diariodeobra.app/v1/obras/{id_obra}/relatorios?dataInicio={data_inicio}&dataFim={data_fim}'
    headers = {
        "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
    }
    try:
        response = requests.get(url, headers=headers)
        print(f"URL: {url}")
        print(f"Status code: {response.status_code}")
        print(f"Resposta bruta: {response.text}")
        
        if response.status_code == 200:
            return response
        else:
            print(f"Erro na requisição: Status {response.status_code}")
            return None  # Retorne None explicitamente para erros
    except Exception as e:
        print(f"Erro ao fazer a requisição: {e}")
        return None

# %%
import requests

# %%
def PegarObras():
  # URL da API que você deseja acessar

  url=f'https://apiexterna.diariodeobra.app/v1/obras'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      print("Status code:", response.status_code)
      print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          print(response.content)
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)
#Pegar ID das obras-------------------------------------------------------------------
"""
Essa função retorna um vetor de ID's das obras da LMI na SAMARCO
"""
def RetornaVetorIdObras():
  obras = PegarObras()
  obras_id=[]
  for obra in obras.json():
    obras_id.append(obra['_id'])
  return obras_id

# %%
vetor=RetornaVetorIdObras()
# Out:
# Status code: 200
# Resposta bruta: [{"_id":"67b86794697780816708c0d2","nome":"ADM - LMI PROJETO MOMENTO III","totalRelatorios":31,"totalFotos":0,"status":{"id":3,"descricao":"Em Andamento"},"created":"21\/02\/2025 08:46:28","modified":"09\/04\/2025 13:44:37"},{"_id":"65859bfe2102858e56062f84","nome":"ALMOXARIFADO","totalRelatorios":272,"totalFotos":1044,"status":{"id":3,"descricao":"Em Andamento"},"created":"22\/12\/2023 11:23:58","modified":"11\/04\/2025 14:14:51"},{"_id":"65fc3412adbaa9eff70fa3f2","nome":"CAMINHONETE 4X2 (GGA)","totalRelatorios":15,"totalFotos":31,"status":{"id":3,"descricao":"Em Andamento"},"created":"21\/03\/2024 10:20:18","modified":"25\/03\/2025 10:38:10"},{"_id":"65d4a2d0e071d51a750a5985","nome":"CAMINHONETE 4X2 (GMU)","totalRelatorios":16,"totalFotos":0,"status":{"id":3,"descricao":"Em Andamento"},"created":"20\/02\/2024 10:02:08","modified":"25\/03\/2025 10:38:35"},{"_id":"658c457f5c026e631e011ac3","nome":"FERROPORT - REFOR\u00c7O ESTRUTURAL","totalRelatorios":447,"totalFotos":1189,"status":{"id":3,"descricao":"Em Andamento"},"created":"27\/12\/2023 12:40:47","modified":"10\/04\/2025 09:41:27"},{"_id":"65859eca3d30cfd268041e99","nome":"FILTRAGEM","totalRelatorios":333,"totalFotos":4001,"status":{"id":3,"descricao":"Em Andamento"},"created":"22\/12\/2023 11:35:54","modified":"11\/04\/2025 16:23:34"},{"_id":"66045fa186b2a727640ba6e4","nome":"GGA - ADM - ROTINA","totalRelatorios":293,"totalFotos":0,"status":{"id":3,"descricao":"Em Andamento"},"created":"27
"status":{"id":3,"descricao":"Em Andamento"},"created":"26\\/11\\/2024 13:11:52","modified":"11\\/04\\/2025 15:01:59"},{"_id":"66d706b97673fdaf8c072e04","nome":"GGA - Sistema combate a inc\\u00eandio transportadora Ubu","totalRelatorios":103,"totalFotos":618,"status":{"id":3,"descricao":"Em Andamento"},"created":"03\\/09\\/2024 09:53:13","modif ...

# %%
todosrelatorios=PegarRelatoriosObra(vetor,'2024-06-12','2025-06-04')
# Out:
# URL: https://apiexterna.diariodeobra.app/v1/obras/['67b86794697780816708c0d2', '65859bfe2102858e56062f84', '65fc3412adbaa9eff70fa3f2', '65d4a2d0e071d51a750a5985', '658c457f5c026e631e011ac3', '65859eca3d30cfd268041e99', '66045fa186b2a727640ba6e4', '66cc84b92253c1098301ef32', '67d9b3c678af9a4120090576', '6745d0a70e722ea8ab0f1474', '67bc828b573d6412cb080fa4', '6792802a6374d523600b1733', '6790ce01e34a8de8e209eb65', '67d313ab4d3c97aabe028af2', '675993576728f2d1550bdbc4', '6745f3487741b65c6501a1e3', '66d706b97673fdaf8c072e04', '67e3eab48776f01e8106c3b2', '67d9b1cf894edfa55601d407', '672902c003884527b3043696', '6589fdceaf78e583cc020a2b', '658acc92df35c5b2d50804e3', '65b2ac170134203d220f8053', '66cc55bca624ebcaa60b3012', '675ffbcae1dcffd57e0ebbf2', '674d94f4a28d766ea2048f68', '658d97925d268ee5500041d4', '6583047f50e3dc72f50bfe44', '65859e3201c81fbce706f404', '665dccc26ac7560dd7038f22', '65859cad679e0600ab0bcf52', '67123a6a9c9ae4c9a0066fd6', '65d4a602d904e557580e8066', '658427bed6894e5531039a75', '6683ea548f9391359a074682', '664c709c26fab8168d0b172c', '65cf4021cf8554e55c0f3e1e', '658afddbd63e81125f0c4b49', '65a8f4b524dab989590d44b5', '65a564dc4e9a952bc5019d13', '658bfdfc1af632d5200a1074', '658c148b11c42de4a30bbe72', '660189bce1b14757c606bf44', '66b499849978d953940b5315', '6596a951dcaf27b3b6025ae4', '66a8f95d7c2a43323e09b3d2', '65b0ff8edf3dcefd1d0d7352', '6745d63ac9a48e9c46082e15', '6708169e800ce7def40d976a', '658aad7dacb99c16280958c7', '672382fa7a0b8b6ad00351d2', '66fbe9f0eeff090ae204adb4', '678fae7234f5a4e94e04dd14', '6798e6776486eac9dc033272', '6760072aa6809a01260af356', '66d6e3ea87c07efb4f05a724', '667be8c2f7f4f5b9660a3212', '658aaac65e80edeb6b064ae9', '65a7c15de1d8237d0500dc76', '67a0a1f13b46337a8d026dfb', '67a0a1527d6bcbaec50c35f5', '65859de59faa8ed8420b1694', '65d49ef3b90b9c056508c713', '664bd574cfc3848e3d0d9d42']/relatorios?dataInicio=2024-06-12&dataFim=2025-06-04
# Status code: 200
# Resposta bruta: []

# %%
todosrelatorios.json()
# Out:
# []

# %%
import requests
import pandas as pd
from io import StringIO
import streamlit as st
import time
import io
import os
#Cria dataframe de uma string-----------------------------------------------------------------
def create_dataframe_from_string(data_str: str) -> pd.DataFrame:
    """
    Given a multi-line string with tab-separated values,
    returns a pandas DataFrame.
    """
    # Use StringIO to simulate a file-like object from the string.
    data_io = StringIO(data_str)
    # Read the data into a DataFrame, assuming tab as the delimiter.
    df = pd.read_csv(data_io, delimiter="\t")
    return df
#Corrigir Dados-------------------------------------------------------------------
"""
Essa função corrige os dados do arquivo excel, para que seja possível realizar a análise.
Adequando a tabela dada a uma tabela de referencia
"""
def CorrigirDados(df, df_referencia):
    for index, row in df.iterrows():
        if row['Nome'] in df_referencia['Nome Errado'].values:
            # Look up the correct name where 'Nome Errado' matches the current name
            correct_name = df_referencia.loc[
                df_referencia['Nome Errado'] == row['Nome'], 'Nome Correto'
            ].values[0]
            # Update the DataFrame using .at (iterrows() returns a copy, so direct assignment won't update the df)
            df.at[index, 'Nome'] = correct_name
    return df
#Pegar Obras RDO-------------------------------------------------------------------
"""
Essa função retorna um vetor de objetos obras da LMI na SAMARCO
"""
def PegarObras():
  # URL da API que você deseja acessar

  url=f'https://apiexterna.diariodeobra.app/v1/obras'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      print("Status code:", response.status_code)
      print("Resposta bruta:", response.text)  # Para inspecionar o que está vindo

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          print(response.content)
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)
#Pegar ID das obras-------------------------------------------------------------------
"""
Essa função retorna um vetor de ID's das obras da LMI na SAMARCO
"""
def RetornaVetorIdObras():
  obras = PegarObras()
  obras_id=[]
  for obra in obras.json():
    obras_id.append(obra['_id'])
  return obras_id
#Pegar relatorio de obras-------------------------------------------------------------------
"""
Essa função retorna todos os relatórios de uma obra a partir do ID da obra
"""
def PegarRelatoriosObra(id_obra,data_inicio='2025-02-28',data_fim='2025-02-28'):
  url=f'https://apiexterna.diariodeobra.app/v1/obras/{id_obra}/relatorios?dataInicio={data_inicio}&dataFim={data_fim}'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)

      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)
#Pegar todos os relatórios das obras-------------------------------------------------------------------
"""
Dado um vetor de id de obras essa função ira retornar um vetor no 
formato:
 [ {id_obra_1:[id_relatorio_1,id_relatorio_2,...]},{id_obra_2:[]},...,{id_obra_n:[id_relatorio_1,...]}]
"""
def PegarTodosRelatoriosObras(obras_id, data_inicio, data_fim):
    ids_relatorios_obras = []
    for obra_id in obras_id:
        if obra_id:  # Check if obra_id is not empty or None
            relatorios = PegarRelatoriosObra(obra_id, data_inicio, data_fim)
            report_ids = []
            for relatorio in relatorios.json():
                report_ids.append(relatorio['_id'])
            # Only add the dictionary if there is at least one report
            if report_ids:
                ids_relatorios_obras.append({obra_id: report_ids})
    return ids_relatorios_obras
#Visualizar Relatório---------------------------------------------------------------------------------
"""
Essa funcao dado um id de obra e id de relatório reotnar a mão de obra
"""
def VisualizarRelatorio(id_obra,id_relatorio):
  url=f'https://apiexterna.diariodeobra.app/v1/obras/{id_obra}/relatorios/{id_relatorio}'

  # Fazendo a requisição GET
  headers = {
      "token": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..74vzOV4gk2gYT9ay8kKqEC58LFu5yj-5TDtIgLy1yNU'
  }
  response = requests.get(url, headers=headers)

  try:
      response = requests.get(url, headers=headers)


      # Somente tente converter em JSON se o status for 200 (ou conforme a API)
      if response.status_code == 200:
          return response
      else:
          print("A requisição não retornou 200. Verifique a mensagem acima.")

  except Exception as e:
      print("Ocorreu um erro ao fazer a requisição:", e)


#RetornarDataNumeroNomeObra--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def RetornaDataNumeroNomeObra(id_obra, id_relatorio, data_inicio='2025-02-28', data_fim='2025-02-28'):
    """
    Essa função irá, dado um id_obra e um id_relatorio, iterar por todos os relatórios de uma obra
    e pegar apenas o referente ao id, retornando um array com as seguintes informações:
      - data RDO
      - numero do relatório
      - nome da obra

    Args:
        id_obra (str): Id referente à obra.
        id_relatorio (str): Id referente ao relatório.
        data_inicio (str, opcional): Data inicial do filtro. Padrão '2025-02-28'.
        data_fim (str, opcional): Data final do filtro. Padrão '2025-02-28'.

    Returns:
        list: [ data_RDO,numero_relatorio, nome_obra] ou None se não encontrar.
    """
    # PegarRelatoriosObra deve retornar algo que, ao chamar .json(), vire uma lista de dicionários
    relatorio = PegarRelatoriosObra(id_obra, data_inicio, data_fim)
    relatorio = relatorio.json()

    for r in relatorio:
        if r['_id'] == id_relatorio:
            # Ajuste aqui para retornar: número do relatório, data, nome da obra
            return [ r['data'],r['numero'], r['obra']['nome']]

    # Caso não encontre o relatório com o id especificado
    return None
#Criando tabela de Mão de Obras----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
"""
Essa função irá receber uma array mão de obras da forma:

[{'id_mao_obra_1':['id_relatorio_1',...]}...]

Essa função irá criar um dataframe com cada pessoa dos relatórios e assim retornar esse dataframe com as seguintes informações:

- numero relatorio.
- data RDO.
- Nome obra.
- Nome.
- Nome empresa.
- Não conforme?.
- Intervalo Hora.
- horario SAM.
- horario RDO.
- incosistencia Acesso.
- valor total horas trabalhadas
"""
def CriaRelatorioObra(vetorObraRelatorio):
    """
    Cria um DataFrame de relatórios de obras.

    Args:
        vetorObraRelatorio (list): lista de dicionários no formato:
            [
              {id_obra_1: [id_relatorio_1, id_relatorio_2, ...]},
              {id_obra_2: [id_relatorio_1, ...]},
              ...
              {id_obra_n: [id_relatorio_1, ...]}
            ]

    Returns:
        pd.DataFrame: com as colunas:
            - Numero Relatorio
            - Data RDO
            - Nome Obra
            - Nome Pessoa
            - Nome Empresa
            - Nome Func.
            - Nao Conforme?
            - Intervalo Hora
            - Horario SAM
            - Horario RDO
            - Incosisten. Acesso
            - Valor Horas Trabalhadas
    """
    columns = [
        'Numero Relatorio',
        'Data RDO',
        'Nome Obra',
        'Nome',
        'Nome Empresa',
        'Nao Conforme?',
        'Intervalo Hora',
        'Horario SAM',
        'Horario RDO',
        'Incosisten. Acesso',
        'Valor Horas Trabalhadas'
    ]
    df = pd.DataFrame(columns=columns)

    # vetorObraRelatorio é algo como [{id_obra1: [rel1, rel2]}, {id_obra2: [...]}]
    for elemento in vetorObraRelatorio:
        # elemento é um dicionário, pegamos a chave e o valor (lista de relatórios)
        id_obra = list(elemento.keys())[0]
        lista_relatorios = elemento[id_obra]

        for relatorio in lista_relatorios:
            # A função VisualizarRelatorio deve retornar o JSON com as pessoas:
            pessoas = VisualizarRelatorio(id_obra, relatorio).json()['maoDeObra']['personalizada']

            # Supondo que RetornaDataNumeroNomeObra retorne [data_RDO, numero, nome_obra]
            data_RDO, numero, nome_obra = RetornaDataNumeroNomeObra(id_obra, relatorio)

            # Montar uma linha do DataFrame para cada pessoa
            for pessoa in pessoas:
                row_data = [
                    numero,                          # Numero Relatorio
                    data_RDO,                        # Data RDO
                    nome_obra,                       # Nome Obra
                    pessoa.get('nome', ''),          # Nome Pessoa
                    'LMI',                           # Nome Empresa (ajuste se necessário)
                    0,                               # Nao Conforme? (ou False, se quiser boolean)
                    '',                              # Intervalo Hora (ex.: diferença de horas, se houver)
                    '',                              # Horario SAM (preencha se tiver a info)
                    pessoa.get('horaInicio', ''),    # Horario RDO (ou horaFim, conforme sua lógica)
                    '',                              # Incosisten. Acesso (preencha se necessário)
                    pessoa.get('horasTrabalhadas', 0)# Valor Horas Trabalhadas
                ]

                # Inserir a nova linha no DataFrame
                df.loc[len(df)] = row_data

    return df
#ConferenciaBases-------------------------------------------------------------------------------------------------------
import pandas as pd

def ConferenciaBases(df: pd.DataFrame, df_acesso: pd.DataFrame) -> pd.DataFrame:
    """
    Função que realiza a conferência entre as bases `df` e `df_acesso`, verificando inconsistências de acesso,
    calculando diferenças de horário e classificando registros como "Não Conforme" quando necessário.

    Parâmetros:
    - df: DataFrame principal contendo os registros de entrada e saída.
    - df_acesso: DataFrame contendo os horários de acesso dos funcionários.

    Retorno:
    - DataFrame `df` atualizado com as colunas 'Horario SAM', 'Intervalo Hora' e 'Nao Conforme?' preenchidas corretamente.
    """

    # Formatação inicial das colunas de data e horário
    # Converter 'Horario RDO' para datetime e depois para string HH:MM
    df['Horario RDO'] = pd.to_datetime(df['Horario RDO'], format='%H:%M', errors='coerce').dt.strftime('%H:%M')
    df['Data RDO'] = pd.to_datetime(df['Data RDO'], dayfirst=True, errors='coerce')
    df_acesso['1ª Acesso'] = pd.to_datetime(df_acesso['1ª Acesso'], format='%H:%M', errors='coerce')
    df_acesso['DT Acesso'] = pd.to_datetime(df_acesso['DT Acesso'], dayfirst=True, errors='coerce')

    # Inicializar colunas se não existirem
    df['Nao Conforme?'] = df.get('Nao Conforme?', 'Não').astype(str)
    df['Horario SAM'] = df.get('Horario SAM', pd.NaT)
    df['Intervalo Hora'] = df.get('Intervalo Hora', pd.NaT)

    # Marca inconsistências de acesso
    df['Incosisten. Acesso'] = df['Nome'].apply(lambda x: 'Não' if x in df_acesso['Nome'].values else 'Sim')

    # Iteração sobre o DataFrame para conferência dos horários
    for index, row in df.iterrows():
        if row['Nome'] in df_acesso['Nome'].values:  # Se o nome estiver na base de acesso
            acessos_filtrados = df_acesso[(df_acesso['Nome'] == row['Nome']) &
                                        (df_acesso['DT Acesso'] == row['Data RDO'])]

            if not acessos_filtrados.empty:
                row_acesso = acessos_filtrados.iloc[0]  # Pega o primeiro acesso encontrado

                # Converter 'Horario RDO' de volta para datetime para cálculos
                horario_rdo = pd.to_datetime(row['Horario RDO'], format='%H:%M', errors='coerce')
                horario_sam = row_acesso['1ª Acesso']

                # Verifica se os horários são válidos
                if pd.isna(horario_rdo) or pd.isna(horario_sam):
                    continue  # Pula a iteração se houver valores inválidos

                # Combinar data de 'Data RDO' com os horários para cálculo correto
                data_base = row['Data RDO']
                if pd.notna(data_base):
                    horario_rdo_completo = pd.Timestamp.combine(data_base.date(), horario_rdo.time())
                    horario_sam_completo = pd.Timestamp.combine(data_base.date(), horario_sam.time())

                    # Calcula a diferença em horas (decimal)
                    intervalo_hora = (horario_sam_completo - horario_rdo_completo).total_seconds() / 3600

                    # Converter para formato HH:MM
                    intervalo_abs = abs(intervalo_hora)  # Usa o valor absoluto
                    horas = int(intervalo_abs)
                    minutos = int((intervalo_abs - horas) * 60)
                    intervalo_formatado = f"{horas:02d}:{minutos:02d}"

                    # Atribuir valores às colunas
                    df.at[index, 'Horario SAM'] = horario_sam.strftime('%H:%M')
                    df.at[index, 'Horario RDO'] = horario_rdo.strftime('%H:%M')  # Garantir que seja apenas HH:MM
                    df.at[index, 'Intervalo Hora'] = intervalo_formatado  # Armazena como HH:MM
                    df.at[index, 'Nao Conforme?'] = 'Sim' if intervalo_abs >= 0.5 else 'Não'

    return df

#ExecutarAnalise---------------------------------------------------------------------------
data = """Nome Errado\tNome Correto
ALCILENE ALMEIDA DA VITORIA FRACALOSSI\tALCILENE ALMEIDA
ANDREA CRISTINA OLIVEIRA\tANDREA CRISTINA DE OLIVEIRA
CLEBERSON FRANCISCO FRANCA PEREIRA\tCLEBERSON FRANCISCO FRANCA
DANIEL GONCALVES DA SILVA\tDANIEL GONÇALVES DA SILVA
DIONES RODRIGO SILVA TEXEIRA\tDIONES RODRIGO SILVA TEIXEIRA
FILIPE  ALMEIDA DA VITORIA\tFILIPE ALMEIDA DA VITORIA
GUILHERME MARCHESI NOGUEIRA\tGUILHERME MARCHEZI NOGUEIRA
JACKSON CARNEIRO CORRE\tJACKSON CARNEIRO CORREA
JEFERSON BOMFIM REIS\tJEFERSON BOMFIM REIS
MAURO JORGE ALVES DE SOUZA\tMAURO JORGE ALVES
MIQUEIAS DE ALMEIDA BARCELOS\tMIQUEIAS DE ALMEIDA BAECELOS
RHUAN SANTOS OLIVEIRA\tRUHAN SANTOS OLIVEIRA
THIAGO ANSELMO  FERREIRA SIMAO\tTHIAGO ANSELMO FERREIRA SIMAO
VINICIUS PIMENTEL SCHUTLZ\tVINICIUS PIMENTEL SCHUTZ
WENYS VENANCIO MONTEIRO\tWENIS VENANCIO MONTEIRO
GERALDO CARLOS SOUZA NETO\tGERALDO CARLOS DE SOUZA NETO
MAXIMO JOSE ROSA SANT'ANA\tMAXIMO JOSE ROSA SANT ANA
CLAUDENBERG SOUZA DE OLIVEIRA\tCLAUDEMBERG SOUZA OLIVEIRA
JEFERSON BOMFIM REIS (96000534)\tJEFERSON BOMFIM REIS
"""
def VerificarHoraExcedente(hora_entrada):
  if hora_entrada is None:
      return 0

  hora = int(hora_entrada.split(":")[0])
  minuto =int( hora_entrada.split(":")[1])
  df = minuto - 14 
  if hora == 9 and df > 0:
    return df/60
  elif hora > 9:
      return abs(df)/60+ (hora - 9)
def ExecutarAnalise(df_entrada,data_inicio,data_fim):
    """
    Funcao responsável por executar a análise pegando a base de dado de entrada para validação.
    data de inicio e a data fim, gerando um dataframe final com os dados.
    """
    df_referencia = create_dataframe_from_string(data)
    df_acesso= CorrigirDados(df_entrada, df_referencia)
    
    #Id_Obras---------------------------------------------------------------------------------------
    inicio = time.time() 
    obras_id = RetornaVetorIdObras()
    fim  = time.time()
    st.write(f'Tempo para executar:RetornaVetorIdObras  {fim-inicio}')
    #Retornar todos os relatorios de um Id_Obra------------------------------------------------------
    sum = 0
    inicio = time.time()
    ids_relatorios = PegarTodosRelatoriosObras(obras_id,data_inicio,data_fim)
    fim  = time.time()
    st.write(f'Tempo para executar:PegarTodosRelatoriosObras  {fim-inicio}')
    sum+=fim-inicio
    inicio = time.time()
    df = CriaRelatorioObra(ids_relatorios)
    fim  = time.time()
    st.write(f'Tempo para executar:CriaRelatorioObra  {fim-inicio}')
    sum+=fim-inicio
    df = CorrigirDados(df,df_referencia)
    inicio = time.time()
    df_final = ConferenciaBases(df,df_acesso)
    fim  = time.time()
    st.write(f'Tempo para executar:ConferenciaBases  {fim-inicio}')
    sum+=fim-inicio
    df_final['Data RDO'] = df_final['Data RDO'].dt.date
    st.write(f'Tempo Total: {sum}')
    # Usando apply com uma função lambda para aplicar a lógica condicional
    df_final['Tempo Horas Trabalhadas Excedentes'] = df_final['Valor Horas Trabalhadas'].apply(
        lambda x: 0 if not VerificarHoraExcedente(x) else VerificarHoraExcedente(x)
    )

    return df_final
    
#Valida Datas Entrada/ Datas Planilha de Entrada--------------------------------------------------------------

def ValidaDatas(df,data_inicial,data_final):
    """
    Essa funcao recebe um dataframe que refere-se ao dataframe extraido do RDO
    e verifica se o intervalo de data fornecido pelo usuario corresponde ao que 
    esta na planilha
    args:
        df: Dataframe
        data_inicial: Data Inicial Streamlit
        data_final: Data Final Streamlit
    """
    data_minima = str(df['DT Acesso'].min()).split(' ')[0]
    data_maxima = str(df['DT Acesso'].max()).split(' ')[0]
    if data_minima == str(data_inicial) and str(data_final) == data_maxima:
        return True
    else: 
        return False
#Salvar Dataframe como Excel-----------------------------------------------------------------
def salvar_dataframe_em_excel(df: pd.DataFrame) -> io.BytesIO:
    """
    Converte um DataFrame em um buffer binário no formato Excel (.xlsx).

    Parâmetros:
    - df: DataFrame a ser convertido.

    Retorna:
    - buffer: Um objeto BytesIO contendo o arquivo Excel.

    Levanta:
    - ValueError: Se o DataFrame for inválido.
    - Exception: Se houver erro ao converter para Excel.
    """
    if not isinstance(df, pd.DataFrame):
        raise ValueError("O argumento 'df' deve ser um pandas DataFrame.")
    if df.empty:
        raise ValueError("O DataFrame está vazio. Não é possível gerar um arquivo Excel.")
    
    try:
        buffer = io.BytesIO()
        with pd.ExcelWriter(buffer, engine='openpyxl') as writer:
            df.to_excel(writer, index=False)
        buffer.seek(0)  # Volta o ponteiro para o início do buffer
        return buffer
    except Exception as e:
        raise Exception(f"Erro ao converter o DataFrame para Excel: {e}")
    
#Verificar Arquivo Excel----------------------------------------------------------------------
def verificar_arquivo_excel(caminho_arquivo: str) -> bool:
    """
    Verifica se um arquivo Excel existe e pode ser lido.

    Parâmetros:
    - caminho_arquivo (str): Caminho completo ou relativo do arquivo Excel (.xlsx ou .xls).

    Retorna:
    - bool: True se o arquivo existe e pode ser lido, False caso contrário.
    """
    try:
        # Verifica se o arquivo existe no sistema de arquivos
        if not os.path.exists(caminho_arquivo):
            return False
        
        # Tenta ler o arquivo Excel
        pd.read_excel(caminho_arquivo, engine='openpyxl')
        return True
    except FileNotFoundError:
        # Arquivo não encontrado
        return False
    except Exception as e:
        # Outros erros (permissão, arquivo corrompido, etc.)
        print(f"Erro ao tentar acessar o arquivo {caminho_arquivo}: {e}")
        return False

# %%
04/04/2025

# %%
vetoridobras=RetornaVetorIdObras()
# Out:
# Status code: 200
# Resposta bruta: [{"_id":"67b86794697780816708c0d2","nome":"ADM - LMI PROJETO MOMENTO III","totalRelatorios":31,"totalFotos":0,"status":{"id":3,"descricao":"Em Andamento"},"created":"21\/02\/2025 08:46:28","modified":"09\/04\/2025 13:44:37"},{"_id":"65859bfe2102858e56062f84","nome":"ALMOXARIFADO","totalRelatorios":272,"totalFotos":1044,"status":{"id":3,"descricao":"Em Andamento"},"created":"22\/12\/2023 11:23:58","modified":"11\/04\/2025 14:14:51"},{"_id":"65fc3412adbaa9eff70fa3f2","nome":"CAMINHONETE 4X2 (GGA)","totalRelatorios":15,"totalFotos":31,"status":{"id":3,"descricao":"Em Andamento"},"created":"21\/03\/2024 10:20:18","modified":"25\/03\/2025 10:38:10"},{"_id":"65d4a2d0e071d51a750a5985","nome":"CAMINHONETE 4X2 (GMU)","totalRelatorios":16,"totalFotos":0,"status":{"id":3,"descricao":"Em Andamento"},"created":"20\/02\/2024 10:02:08","modified":"25\/03\/2025 10:38:35"},{"_id":"658c457f5c026e631e011ac3","nome":"FERROPORT - REFOR\u00c7O ESTRUTURAL","totalRelatorios":447,"totalFotos":1189,"status":{"id":3,"descricao":"Em Andamento"},"created":"27\/12\/2023 12:40:47","modified":"10\/04\/2025 09:41:27"},{"_id":"65859eca3d30cfd268041e99","nome":"FILTRAGEM","totalRelatorios":333,"totalFotos":4001,"status":{"id":3,"descricao":"Em Andamento"},"created":"22\/12\/2023 11:35:54","modified":"11\/04\/2025 16:23:34"},{"_id":"66045fa186b2a727640ba6e4","nome":"GGA - ADM - ROTINA","totalRelatorios":293,"totalFotos":0,"status":{"id":3,"descricao":"Em Andamento"},"created":"27\/03\/2024 15:04:17","modified":"11\/04\/2025 15:54:26"},{"_id":"66cc84b92253c1098301ef32","nome":"GGA - Adequa\u00e7\u00e3o NR12 - UBU","totalRelatorios":109,"totalFotos":1107,"status":{"id":3,"descricao":"Em Andamento"},"created":"26\/08\/2024 10:35:53","modified":"11\/04\/2025 15:13:44"},{"_id":"67d9b3c678af9a4120090576","nome":"GGA - Controle de alimenta\u00e7\u00e3o de \u00e0gua de selagem nas torres de resfriamento","totalRelatorios":20,"totalFotos":115,"status":{"id":3,"descricao":"Em Andamento"},"created":"18\/03\/2025 14:56:22","modified":"11\/04\/2025 17:10:19"},{"_id":"6745d0a70e722ea8ab0f1474","nome":"GGA - GALP\u00c3O DE PSC 4","totalRelatorios":43,"totalFotos":382,"status":{"id":3,"descricao":"Em Andamento"},"created":"26\